# %%
import warnings
import dreamerv3
from dreamerv3 import embodied
warnings.filterwarnings('ignore', '.*truncated to dtype int32.*')

print("Reading config", flush =True)

# See configs.yaml for all options.
config = embodied.Config(dreamerv3.configs['defaults'])
config = config.update(dreamerv3.configs['small'])
config = config.update({
  'logdir': '~/PhD_projects2/dreamer_flows/dreamer/logdir/notebook_test_cyl_ks_9',
  'run.train_ratio': 32,
  'run.log_every': 30,  # seconds
  'batch_size': 16,
  'batch_length': 8,
  'jax.prealloc': False,
    
  'encoder.mlp_keys': 'vector',
#   'encoder.mlp_units': 512,

  'decoder.mlp_keys': 'vector',
#   'decoder.mlp_units': 512,
    
  'encoder.cnn_keys': '$^',
  'decoder.cnn_keys': '$^',
    
#   'reward_head.units': 512,
#   'cont_head.units': 512,
    
  'model_opt.lr': 1e-4,
    
  'jax.platform': 'cpu',
  'wrapper.length': 0,
    
  'envs.amount': 8
})
# config = embodied.Flags(config).parse()

logdir = embodied.Path(config.logdir)
step = embodied.Counter()
logger = embodied.Logger(step, [
  embodied.logger.TerminalOutput(),
  embodied.logger.JSONLOutput(logdir, 'metrics.jsonl'),
  embodied.logger.TensorBoardOutput(logdir),
  # embodied.logger.WandBOutput(logdir.name, config),
  # embodied.logger.MLFlowOutput(logdir.name),
])
# Out:
# 2024-06-05 17:00:09.897955: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Reading config

# %%
import gym
from embodied.envs import from_gym

from cyl.simulation_base.env import resume_env
import numpy as np

print("Setting Up Environment", flush =True)
sim_log_name = config.logdir.split("/")[-1]
env  = resume_env(plot=False, dump_CL=False, dump_vtu=False, dump_debug=10, log_name = sim_log_name)
# Out:
# --------------------------------------------------------------------------
# No OpenFabrics connection schemes reported that they were able to be
# used on a specific port.  As such, the openib BTL (OpenFabrics
# support) will be disabled for this port.
#
#   Local host:           cx3-15-29
#   Local device:         mlx5_0
#   Local port:           1
#   CPCs attempted:       rdmacm, udcm
# --------------------------------------------------------------------------
# bash: which: line 1: syntax error: unexpected end of file
# bash: error importing function definition for `which'
# bash: module: line 1: syntax error: unexpected end of file
# bash: error importing function definition for `module'
# bash: scl: line 1: syntax error: unexpected end of file
# bash: error importing function definition for `scl'
# bash: ml: line 1: syntax error: unexpected end of file
# bash: error importing function definition for `ml'
# bash: which: line 1: syntax error: unexpected end of file
# bash: error importing function definition for `which'
# bash: module: line 1: syntax error: unexpected end of file
# bash: error importing function definition for `module'
# bash: scl: line 1: syntax error: unexpected end of file
# bash: error importing function definition for `scl'
# bash: ml: line 1: syntax error: unexpected end of file
# bash: error importing function definition for `ml'
# iUFL can be obtained from https://github.com/MiroK/ufl-interpreter
# Setting Up Environment
# Number of probes: 64
# test cwd env:  /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer
# Simulated 729 iterations before starting the control
# --- done buffers initialisation ---

# %%
env = from_gym.FromGym(env, obs_key='vector')  # Or obs_key='vector'.
env = dreamerv3.wrap_env(env, config)
env = embodied.BatchEnv([env], parallel=False)

# %%
agent = dreamerv3.Agent(env.obs_space, env.act_space, step, config)

# %%
replay = embodied.replay.Uniform(
  config.batch_length, config.replay_size, logdir / 'replay')

args = embodied.Config(
  **config.run, logdir=config.logdir,
  batch_steps=config.batch_size * config.batch_length)

# %%
len(replay)

# %% [markdown]
# Train the Model

# %%
embodied.run.train(agent, env, replay, logger, args)
# Out:
# Logdir /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/logdir/notebook_test_cyl_ks_9
# Observation space:
#   vector           Space(dtype=float32, shape=(66,), low=-inf, high=inf)
#   reward           Space(dtype=float32, shape=(), low=-inf, high=inf)
#   is_first         Space(dtype=bool, shape=(), low=False, high=True)
#   is_last          Space(dtype=bool, shape=(), low=False, high=True)
#   is_terminal      Space(dtype=bool, shape=(), low=False, high=True)
# Action space:
#   action           Space(dtype=float32, shape=(2,), low=-1.0, high=1.0)
#   reset            Space(dtype=bool, shape=(), low=False, high=True)
# Prefill train dataset.
# len replay in driver:  0
# max() in driver:  128
# len replay in driver:  0
# step in driver:  0
# Number of probes: 64
# test cwd env:  /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer
# Simulated 369 iterations before starting the control
# step in driver:  1
# step in driver:  2
# step in driver:  3
# step in driver:  4
# step in driver:  5
# step in driver:  6
# step in driver:  7
# step in driver:  8
# step in driver:  9
# step in driver:  10
# step in driver:  11
# step in driver:  12
# step in driver:  13
# step in driver:  14
# step in driver:  15
# step in driver:  16
# step in driver:  17
# step in driver:  18
# step in driver:  19
# step in driver:  20
# step in driver:  21
# step in driver:  22
# step in driver:  23
# step in driver:  24
# step in driver:  25
# step in driver:  26
# step in driver:  27
# step in driver:  28
# step in driver:  29
# step in driver:  30
# step in driver:  31
# step in driver:  32
# step in driver:  33
# step in driver:  34
# step in driver:  35
# step in driver:  36
# step in driver:  37
# step in driver:  38
# step in driver:  39
# step in driver:  40
# step in driver:  41
# step in driver:  42
# step in driver:  43
# step in driver:  44
# step in driver:  45
# step in driver:  46
# step in driver:  47
# step in driver:  48
# step in driver:  49
# step in driver:  50
# step in driver:  51
# step in driver:  52
# step in driver:  53
# step in driver:  54
# step in driver:  55
# step in driver:  56
# step in driver:  57
# step in driver:  58
# step in driver:  59
# step in driver:  60
# step in driver:  61
# step in driver:  62
# step in driver:  63
# step in driver:  64
# step in driver:  65
# step in driver:  66
# step in driver:  67
# step in driver:  68
# step in driver:  69
# step in driver:  70
# step in driver:  71
# step in driver:  72
# step in driver:  73
# step in driver:  74
# step in driver:  75
# step in driver:  76
# step in driver:  77
# step in driver:  78
# step in driver:  79
# step in driver:  80
# step in driver:  81
# step in driver:  82
# step in driver:  83
# step in driver:  84
# step in driver:  85
# step in driver:  86
# step in driver:  87
# step in driver:  88
# step in driver:  89
# step in driver:  90
# step in driver:  91
# step in driver:  92
# step in driver:  93
# step in driver:  94
# step in driver:  95
# step in driver:  96
# step in driver:  97
# step in driver:  98
# step in driver:  99
# len replay in driver:  93
# step in driver:  0
# step in driver:  1
# step in driver:  2
# step in driver:  3
# step in driver:  4
# step in driver:  5
# step in driver:  6
# step in driver:  7
# step in driver:  8
# step in driver:  9
# step in driver:  10
# step in driver:  11
# step in driver:  12
# step in driver:  13
# step in driver:  14
# step in driver:  15
# step in driver:  16
# step in driver:  17
# step in driver:  18
# step in driver:  19
# step in driver:  20
# step in driver:  21
# step in driver:  22
# step in driver:  23
# step in driver:  24
# step in driver:  25
# step in driver:  26
# step in driver:  27
# step in driver:  28
# step in driver:  29
# step in driver:  30
# step in driver:  31
# step in driver:  32
# step in driver:  33
# step in driver:  34
# step in driver:  35
# step in driver:  36
# step in driver:  37
# step in driver:  38
# step in driver:  39
# step in driver:  40
# step in driver:  41
# step in driver:  42
# step in driver:  43
# step in driver:  44
# step in driver:  45
# step in driver:  46
# step in driver:  47
# step in driver:  48
# step in driver:  49
# step in driver:  50
# step in driver:  51
# step in driver:  52
# step in driver:  53
# step in driver:  54
# step in driver:  55
# step in driver:  56
# step in driver:  57
# step in driver:  58
# step in driver:  59
# step in driver:  60
# step in driver:  61
# step in driver:  62
# step in driver:  63
# step in driver:  64
# step in driver:  65
# step in driver:  66
# step in driver:  67
# step in driver:  68
# step in driver:  69
# step in driver:  70
# step in driver:  71
# step in driver:  72
# step in driver:  73
# step in driver:  74
# step in driver:  75
# step in driver:  76
# step in driver:  77
# step in driver:  78
# step in driver:  79
# step in driver:  80
# step in driver:  81
# step in driver:  82
# step in driver:  83
# step in driver:  84
# step in driver:  85
# step in driver:  86
# step in driver:  87
# step in driver:  88
# step in driver:  89
# step in driver:  90
# step in driver:  91
# step in driver:  92
# step in driver:  93
# step in driver:  94
# step in driver:  95
# step in driver:  96
# step in driver:  97
# step in driver:  98
# step in driver:  99
# Done Prefill train dataset.
# Did not find any checkpoint.
# Writing checkpoint: /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/logdir/notebook_test_cyl_ks_9/checkpoint.ckpt
# Start training loop.
# step in driver:  0
# Wrote checkpoint: /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/logdir/notebook_test_cyl_ks_9/checkpoint.ckpt
# Saved chunk: 20240605T131009F949854-6E0KALu1rwKCBGMJmfv1Ji-0000000000000000000000-200.npz
# Tracing policy function.
# Tracing policy function.
# Tracing train function.
# Tracing report function.
# Tracing report function.
# ──────────────────────────────────────────────────── Step 201 ─────────────────────────────────────────────────────
# train/action_mag 3.97 / train/action_max 3.97 / train/action_mean 0.72 / train/action_min -2.66 / train/action_std
# 0.91 / train/actor_opt_actor_opt_grad_overflow 0 / train/actor_opt_actor_opt_grad_scale 1e4 /
# train/actor_opt_grad_norm 1.6e-4 / train/actor_opt_grad_steps 1 / train/actor_opt_loss -1.3 / train/adv_mag 1.5e-4
# / train/adv_max -9.9e-6 / train/adv_mean -3e-5 / train/adv_min -1.5e-4 / train/adv_std 2.1e-5 / train/cont_avg 1 /
# train/cont_loss_mean 1.03 / train/cont_loss_std 0.4 / train/cont_neg_acc nan / train/cont_neg_loss nan /
# train/cont_pos_acc 0.2 / train/cont_pos_loss 1.03 / train/cont_pred 0.39 / train/cont_rate 1 / train/dyn_loss_mean
# 6.92 / train/dyn_loss_std 0.32 / train/extr_critic_critic_opt_critic_opt_grad_overflow 0 /
# train/extr_critic_critic_opt_critic_opt_grad_scale 1e4 / train/extr_critic_critic_opt_grad_norm 2.74 /
# train/extr_critic_critic_opt_grad_steps 1 / train/extr_critic_critic_opt_loss 2e4 / train/extr_critic_mag 1.2e-7 /
# train/extr_critic_max 1.2e-7 / train/extr_critic_mean 1.2e-7 / train/extr_critic_min 1.2e-7 / train/extr_critic_std
# 0 / train/extr_return_normed_mag 1.5e-4 / train/extr_return_normed_max -9e-6 / train/extr_return_normed_mean
# -2.9e-5 / train/extr_return_normed_min -1.5e-4 / train/extr_return_normed_std 2.1e-5 / train/extr_return_rate 0 /
# train/extr_return_raw_mag 1.5e-4 / train/extr_return_raw_max -9.8e-6 / train/extr_return_raw_mean -2.9e-5 /
# train/extr_return_raw_min -1.5e-4 / train/extr_return_raw_std 2.1e-5 / train/extr_reward_mag 1.6e-5 /
# train/extr_reward_max -8.8e-6 / train/extr_reward_mean -1.3e-5 / train/extr_reward_min -1.6e-5 /
# train/extr_reward_std 1.1e-6 / train/model_loss_mean 64.49 / train/model_loss_std 8.8 / train/model_opt_grad_norm
# 374.3 / train/model_opt_grad_steps 1 / train/model_opt_loss 6.4e5 / train/model_opt_model_opt_grad_overflow 0 /
# train/model_opt_model_opt_grad_scale 1e4 / train/policy_entropy_mag 2.78 / train/policy_entropy_max 2.78 /
# train/policy_entropy_mean 2.56 / train/policy_entropy_min 1.7 / train/policy_entropy_std 0.13 /
# train/policy_logprob_mag 11.23 / train/policy_logprob_max -0.85 / train/policy_logprob_mean -2.52 /
# train/policy_logprob_min -11.23 / train/policy_logprob_std 0.98 / train/policy_randomness_mag 0.99 /
# train/policy_randomness_max 0.99 / train/policy_randomness_mean 0.94 / train/policy_randomness_min 0.75 /
# train/policy_randomness_std 0.03 / train/post_ent_mag 107.67 / train/post_ent_max 107.67 / train/post_ent_mean
# 107.43 / train/post_ent_min 107.2 / train/post_ent_std 0.11 / train/prior_ent_mag 108.14 / train/prior_ent_max
# 108.14 / train/prior_ent_mean 107.5 / train/prior_ent_min 106.87 / train/prior_ent_std 0.23 / train/rep_loss_mean
# 6.92 / train/rep_loss_std 0.32 / train/reward_avg -0.02 / train/reward_loss_mean 5.54 / train/reward_loss_std
# 2.4e-6 / train/reward_max_data 0.1 / train/reward_max_pred 1.2e-7 / train/reward_neg_acc 1 / train/reward_neg_loss
# 5.54 / train/reward_pos_acc nan / train/reward_pos_loss nan / train/reward_pred 1.2e-7 / train/reward_rate 0 /
# train/vector_loss_mean 53.76 / train/vector_loss_std 8.85 / train/params_agent/wm/model_opt 1.7e7 /
# train/params_agent/task_behavior/critic/critic_opt 1.2e6 / train/params_agent/task_behavior/ac/actor_opt 1.1e6 /
# replay/size 194 / replay/inserts 194 / replay/samples 112 / replay/insert_wait_avg 3.2e-6 / replay/insert_wait_frac
# 1 / replay/sample_wait_avg 1.5e-6 / replay/sample_wait_frac 1 / timer/duration 944.72 / timer/env.step_count 201 /
# timer/env.step_total 878.23 / timer/env.step_frac 0.93 / timer/env.step_avg 4.37 / timer/env.step_min 4.2 /
# timer/env.step_max 22.28 / timer/replay.add_count 201 / timer/replay.add_total 0.02 / timer/replay.add_frac 2.4e-5
# / timer/replay.add_avg 1.1e-4 / timer/replay.add_min 8.1e-5 / timer/replay.add_max 2.2e-4 /
# timer/logger.write_count 1 / timer/logger.write_total 1.1e-5 / timer/logger.write_frac 1.2e-8 /
# timer/logger.write_avg 1.1e-5 / timer/logger.write_min 1.1e-5 / timer/logger.write_max 1.1e-5 /
# timer/checkpoint.save_count 1 / timer/checkpoint.save_total 3.5e-3 / timer/checkpoint.save_frac 3.7e-6 /
# timer/checkpoint.save_avg 3.5e-3 / timer/checkpoint.save_min 3.5e-3 / timer/checkpoint.save_max 3.5e-3 /
# timer/agent.save_count 1 / timer/agent.save_total 0.07 / timer/agent.save_frac 7.2e-5 / timer/agent.save_avg 0.07 /
# timer/agent.save_min 0.07 / timer/agent.save_max 0.07 / timer/replay.save_count 1 / timer/replay.save_total 2e-3 /
# timer/replay.save_frac 2.2e-6 / timer/replay.save_avg 2e-3 / timer/replay.save_min 2e-3 / timer/replay.save_max
# 2e-3 / timer/agent.policy_count 1 / timer/agent.policy_total 4.21 / timer/agent.policy_frac 4.5e-3 /
# timer/agent.policy_avg 4.21 / timer/agent.policy_min 4.21 / timer/agent.policy_max 4.21 / timer/dataset_count 1 /
# timer/dataset_total 2.7e-5 / timer/dataset_frac 2.9e-8 / timer/dataset_avg 2.7e-5 / timer/dataset_min 2.7e-5 /
# timer/dataset_max 2.7e-5 / timer/agent.train_count 1 / timer/agent.train_total 55.41 / timer/agent.train_frac 0.06
# / timer/agent.train_avg 55.41 / timer/agent.train_min 55.41 / timer/agent.train_max 55.41 /
# timer/agent.report_count 1 / timer/agent.report_total 6.76 / timer/agent.report_frac 7.2e-3 /
# timer/agent.report_avg 6.76 / timer/agent.report_min 6.76 / timer/agent.report_max 6.76
# Creating new TensorBoard event file writer.
# Episode has 200 steps and return -3.0.
# step in driver:  1
# Mean accumulated drag on the whole episode: -0.7328929233340409
# Number of probes: 64
# test cwd env:  /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer
# Simulated 1122 iterations before starting the control
# step in driver:  2
# step in driver:  3
# step in driver:  4
# step in driver:  5
# step in driver:  6
# step in driver:  7
# step in driver:  8
# step in driver:  9
# ──────────────────────────────────────────────────── Step 210 ─────────────────────────────────────────────────────
# episode/length 200 / episode/score -2.99 / episode/sum_abs_reward 3.14 / episode/reward_rate 0 / report/cont_avg 1
# / report/cont_loss_mean 0.31 / report/cont_loss_std 0.2 / report/cont_neg_acc nan / report/cont_neg_loss nan /
# report/cont_pos_acc 0.94 / report/cont_pos_loss 0.31 / report/cont_pred 0.74 / report/cont_rate 1 /
# report/dyn_loss_mean 7.06 / report/dyn_loss_std 0.38 / report/model_loss_mean 33.46 / report/model_loss_std 4.34 /
# report/post_ent_mag 106.87 / report/post_ent_max 106.87 / report/post_ent_mean 106.56 / report/post_ent_min 106.27
# / report/post_ent_std 0.1 / report/prior_ent_mag 108.14 / report/prior_ent_max 108.14 / report/prior_ent_mean
# 107.73 / report/prior_ent_min 107.06 / report/prior_ent_std 0.2 / report/rep_loss_mean 7.06 / report/rep_loss_std
# 0.38 / report/reward_avg -0.01 / report/reward_loss_mean 5.47 / report/reward_loss_std 5.8e-3 /
# report/reward_max_data 0.07 / report/reward_max_pred 5.2e-5 / report/reward_neg_acc 1 / report/reward_neg_loss 5.47
# / report/reward_pos_acc nan / report/reward_pos_loss nan / report/reward_pred -4.2e-5 / report/reward_rate 0 /
# report/vector_loss_mean 23.44 / report/vector_loss_std 4.29 / replay/size 203 / replay/inserts 9 / replay/samples
# 32 / replay/insert_wait_avg 6.3e-6 / replay/insert_wait_frac 1 / replay/sample_wait_avg 1.8e-6 /
# replay/sample_wait_frac 1 / timer/duration 112.88 / timer/env.step_count 9 / timer/env.step_total 109.96 /
# timer/env.step_frac 0.97 / timer/env.step_avg 12.22 / timer/env.step_min 4.72 / timer/env.step_max 71.85 /
# timer/replay.add_count 9 / timer/replay.add_total 2.3e-3 / timer/replay.add_frac 2.1e-5 / timer/replay.add_avg
# 2.6e-4 / timer/replay.add_min 1.5e-4 / timer/replay.add_max 3.7e-4 / timer/logger.write_count 1 /
# timer/logger.write_total 0.06 / timer/logger.write_frac 5.2e-4 / timer/logger.write_avg 0.06 /
# timer/logger.write_min 0.06 / timer/logger.write_max 0.06 / timer/checkpoint.save_count 0 /
# timer/checkpoint.save_total 0 / timer/checkpoint.save_frac 0 / timer/agent.save_count 0 / timer/agent.save_total 0
# / timer/agent.save_frac 0 / timer/replay.save_count 0 / timer/replay.save_total 0 / timer/replay.save_frac 0 /
# timer/agent.policy_count 9 / timer/agent.policy_total 0.08 / timer/agent.policy_frac 7.5e-4 /
# timer/agent.policy_avg 9.4e-3 / timer/agent.policy_min 7.9e-3 / timer/agent.policy_max 0.01 / timer/dataset_count 2
# / timer/dataset_total 2e-4 / timer/dataset_frac 1.8e-6 / timer/dataset_avg 1e-4 / timer/dataset_min 7.5e-5 /
# timer/dataset_max 1.3e-4 / timer/agent.train_count 2 / timer/agent.train_total 2.29 / timer/agent.train_frac 0.02 /
# timer/agent.train_avg 1.14 / timer/agent.train_min 1.08 / timer/agent.train_max 1.21 / timer/agent.report_count 1 /
# timer/agent.report_total 0.07 / timer/agent.report_frac 5.9e-4 / timer/agent.report_avg 0.07 /
# timer/agent.report_min 0.07 / timer/agent.report_max 0.07 / fps 0.08
# step in driver:  10
# step in driver:  11
# step in driver:  12
# step in driver:  13
# step in driver:  14
# step in driver:  15
# step in driver:  16
# step in driver:  17
# step in driver:  18
# step in driver:  19
# step in driver:  20
# step in driver:  21
# step in driver:  22
# step in driver:  23
# step in driver:  24
# step in driver:  25
# step in driver:  26
# step in driver:  27
# step in driver:  28
# step in driver:  29
# step in driver:  30
# step in driver:  31
# step in driver:  32
# step in driver:  33
# step in driver:  34
# step in driver:  35
# step in driver:  36
# step in driver:  37
# step in driver:  38
# step in driver:  39
# ──────────────────────────────────────────────────── Step 240 ─────────────────────────────────────────────────────
# train/action_mag 3.49 / train/action_max 3.49 / train/action_mean 0.6 / train/action_min -3.26 / train/action_std
# 0.95 / train/actor_opt_actor_opt_grad_overflow 0 / train/actor_opt_actor_opt_grad_scale 1e4 /
# train/actor_opt_grad_norm 8.2e-4 / train/actor_opt_grad_steps 10 / train/actor_opt_loss 3.99 / train/adv_mag 2e-3 /
# train/adv_max -1.7e-4 / train/adv_mean -1.2e-3 / train/adv_min -2e-3 / train/adv_std 5.5e-4 / train/cont_avg 0.98 /
# train/cont_loss_mean 0.12 / train/cont_loss_std 0.69 / train/cont_neg_acc 0 / train/cont_neg_loss 4.55 /
# train/cont_pos_acc 1 / train/cont_pos_loss 0.02 / train/cont_pred 0.98 / train/cont_rate 0.98 / train/dyn_loss_mean
# 6.05 / train/dyn_loss_std 0.37 / train/extr_critic_critic_opt_critic_opt_grad_overflow 0 /
# train/extr_critic_critic_opt_critic_opt_grad_scale 1e4 / train/extr_critic_critic_opt_grad_norm 16.86 /
# train/extr_critic_critic_opt_grad_steps 10 / train/extr_critic_critic_opt_loss 1e5 / train/extr_critic_mag 1.2e-6 /
# train/extr_critic_max 1.2e-7 / train/extr_critic_mean -4.9e-7 / train/extr_critic_min -1.2e-6 /
# train/extr_critic_std 1.9e-7 / train/extr_return_normed_mag 2e-3 / train/extr_return_normed_max -8e-5 /
# train/extr_return_normed_mean -1.1e-3 / train/extr_return_normed_min -2e-3 / train/extr_return_normed_std 5.5e-4 /
# train/extr_return_rate 0 / train/extr_return_raw_mag 2e-3 / train/extr_return_raw_max -1.7e-4 /
# train/extr_return_raw_mean -1.2e-3 / train/extr_return_raw_min -2e-3 / train/extr_return_raw_std 5.5e-4 /
# train/extr_reward_mag 2e-4 / train/extr_reward_max -1.6e-4 / train/extr_reward_mean -1.9e-4 / train/extr_reward_min
# -2e-4 / train/extr_reward_std 5.7e-6 / train/model_loss_mean 15.73 / train/model_loss_std 2.09 /
# train/model_opt_grad_norm 75.36 / train/model_opt_grad_steps 10 / train/model_opt_loss 1.6e5 /
# train/model_opt_model_opt_grad_overflow 0 / train/model_opt_model_opt_grad_scale 1e4 / train/policy_entropy_mag
# 2.79 / train/policy_entropy_max 2.79 / train/policy_entropy_mean 2.61 / train/policy_entropy_min 1.95 /
# train/policy_entropy_std 0.1 / train/policy_logprob_mag 10.24 / train/policy_logprob_max -1.22 /
# train/policy_logprob_mean -2.56 / train/policy_logprob_min -10.24 / train/policy_logprob_std 0.94 /
# train/policy_randomness_mag 0.99 / train/policy_randomness_max 0.99 / train/policy_randomness_mean 0.95 /
# train/policy_randomness_min 0.81 / train/policy_randomness_std 0.02 / train/post_ent_mag 106.46 /
# train/post_ent_max 106.46 / train/post_ent_mean 106.25 / train/post_ent_min 106.12 / train/post_ent_std 0.06 /
# train/prior_ent_mag 108.32 / train/prior_ent_max 108.32 / train/prior_ent_mean 107.92 / train/prior_ent_min 107.37
# / train/prior_ent_std 0.19 / train/rep_loss_mean 6.05 / train/rep_loss_std 0.37 / train/reward_avg -0.02 /
# train/reward_loss_mean 5.28 / train/reward_loss_std 0.01 / train/reward_max_data 0.07 / train/reward_max_pred
# 1.7e-4 / train/reward_neg_acc 1 / train/reward_neg_loss 5.28 / train/reward_pos_acc nan / train/reward_pos_loss nan
# / train/reward_pred -1.6e-4 / train/reward_rate 0 / train/vector_loss_mean 6.7 / train/vector_loss_std 1.84 /
# replay/size 233 / replay/inserts 30 / replay/samples 112 / replay/insert_wait_avg 6.1e-6 / replay/insert_wait_frac
# 1 / replay/sample_wait_avg 1.7e-6 / replay/sample_wait_frac 1 / timer/duration 151.71 / timer/env.step_count 30 /
# timer/env.step_total 143.24 / timer/env.step_frac 0.94 / timer/env.step_avg 4.77 / timer/env.step_min 4.66 /
# timer/env.step_max 4.85 / timer/replay.add_count 30 / timer/replay.add_total 9.4e-3 / timer/replay.add_frac 6.2e-5
# / timer/replay.add_avg 3.1e-4 / timer/replay.add_min 1.8e-4 / timer/replay.add_max 7.8e-4 /
# timer/logger.write_count 1 / timer/logger.write_total 0.01 / timer/logger.write_frac 8.7e-5 /
# timer/logger.write_avg 0.01 / timer/logger.write_min 0.01 / timer/logger.write_max 0.01 /
# timer/checkpoint.save_count 0 / timer/checkpoint.save_total 0 / timer/checkpoint.save_frac 0 /
# timer/agent.save_count 0 / timer/agent.save_total 0 / timer/agent.save_frac 0 / timer/replay.save_count 0 /
# timer/replay.save_total 0 / timer/replay.save_frac 0 / timer/agent.policy_count 30 / timer/agent.policy_total 0.34
# / timer/agent.policy_frac 2.3e-3 / timer/agent.policy_avg 0.01 / timer/agent.policy_min 8.6e-3 /
# timer/agent.policy_max 0.02 / timer/dataset_count 7 / timer/dataset_total 9.5e-4 / timer/dataset_frac 6.3e-6 /
# timer/dataset_avg 1.4e-4 / timer/dataset_min 9.6e-5 / timer/dataset_max 1.6e-4 / timer/agent.train_count 7 /
# timer/agent.train_total 8 / timer/agent.train_frac 0.05 / timer/agent.train_avg 1.14 / timer/agent.train_min 1.1 /
# timer/agent.train_max 1.19 / timer/agent.report_count 1 / timer/agent.report_total 0.09 / timer/agent.report_frac
# 5.8e-4 / timer/agent.report_avg 0.09 / timer/agent.report_min 0.09 / timer/agent.report_max 0.09 / fps 0.2
# step in driver:  40
# step in driver:  41
# step in driver:  42
# step in driver:  43
# step in driver:  44
# step in driver:  45
# step in driver:  46
# step in driver:  47
# step in driver:  48
# step in driver:  49
# step in driver:  50
# step in driver:  51
# step in driver:  52
# step in driver:  53
# step in driver:  54
# step in driver:  55
# step in driver:  56
# step in driver:  57
# step in driver:  58
# step in driver:  59
# step in driver:  60
# step in driver:  61
# step in driver:  62
# step in driver:  63
# step in driver:  64
# step in driver:  65
# step in driver:  66
# step in driver:  67
# step in driver:  68
# step in driver:  69
# ──────────────────────────────────────────────────── Step 270 ─────────────────────────────────────────────────────
# report/cont_avg 0.98 / report/cont_loss_mean 0.1 / report/cont_loss_std 0.79 / report/cont_neg_acc 0 /
# report/cont_neg_loss 6.39 / report/cont_pos_acc 1 / report/cont_pos_loss 2.5e-3 / report/cont_pred 1 /
# report/cont_rate 0.98 / report/dyn_loss_mean 3.77 / report/dyn_loss_std 0.38 / report/model_loss_mean 8.8 /
# report/model_loss_std 1.04 / report/post_ent_mag 106.55 / report/post_ent_max 106.55 / report/post_ent_mean 106.37
# / report/post_ent_min 106.24 / report/post_ent_std 0.06 / report/prior_ent_mag 108.41 / report/prior_ent_max 108.41
# / report/prior_ent_mean 108.04 / report/prior_ent_min 107.67 / report/prior_ent_std 0.16 / report/rep_loss_mean
# 3.77 / report/rep_loss_std 0.38 / report/reward_avg -0.02 / report/reward_loss_mean 4.91 / report/reward_loss_std
# 0.02 / report/reward_max_data 0.1 / report/reward_max_pred 5.1e-4 / report/reward_neg_acc 1 /
# report/reward_neg_loss 4.91 / report/reward_pos_acc nan / report/reward_pos_loss nan / report/reward_pred -4.7e-4 /
# report/reward_rate 0 / report/vector_loss_mean 1.52 / report/vector_loss_std 0.57 / replay/size 263 /
# replay/inserts 30 / replay/samples 128 / replay/insert_wait_avg 5.9e-6 / replay/insert_wait_frac 1 /
# replay/sample_wait_avg 1.9e-6 / replay/sample_wait_frac 1 / timer/duration 151.74 / timer/env.step_count 30 /
# timer/env.step_total 142.45 / timer/env.step_frac 0.94 / timer/env.step_avg 4.75 / timer/env.step_min 4.68 /
# timer/env.step_max 4.92 / timer/replay.add_count 30 / timer/replay.add_total 9.5e-3 / timer/replay.add_frac 6.2e-5
# / timer/replay.add_avg 3.2e-4 / timer/replay.add_min 1.6e-4 / timer/replay.add_max 4.3e-4 /
# timer/logger.write_count 1 / timer/logger.write_total 0.02 / timer/logger.write_frac 1.3e-4 /
# timer/logger.write_avg 0.02 / timer/logger.write_min 0.02 / timer/logger.write_max 0.02 /
# timer/checkpoint.save_count 0 / timer/checkpoint.save_total 0 / timer/checkpoint.save_frac 0 /
# timer/agent.save_count 0 / timer/agent.save_total 0 / timer/agent.save_frac 0 / timer/replay.save_count 0 /
# timer/replay.save_total 0 / timer/replay.save_frac 0 / timer/agent.policy_count 30 / timer/agent.policy_total 0.29
# / timer/agent.policy_frac 1.9e-3 / timer/agent.policy_avg 9.8e-3 / timer/agent.policy_min 8.5e-3 /
# timer/agent.policy_max 0.01 / timer/dataset_count 8 / timer/dataset_total 9.9e-4 / timer/dataset_frac 6.6e-6 /
# timer/dataset_avg 1.2e-4 / timer/dataset_min 9.9e-5 / timer/dataset_max 1.4e-4 / timer/agent.train_count 8 /
# timer/agent.train_total 8.88 / timer/agent.train_frac 0.06 / timer/agent.train_avg 1.11 / timer/agent.train_min
# 1.04 / timer/agent.train_max 1.22 / timer/agent.report_count 1 / timer/agent.report_total 0.08 /
# timer/agent.report_frac 5e-4 / timer/agent.report_avg 0.08 / timer/agent.report_min 0.08 / timer/agent.report_max
# 0.08 / fps 0.2
# step in driver:  70
# step in driver:  71
# step in driver:  72
# step in driver:  73
# step in driver:  74
# step in driver:  75
# step in driver:  76
# step in driver:  77
# step in driver:  78
# step in driver:  79
# step in driver:  80
# step in driver:  81
# step in driver:  82
# step in driver:  83
# step in driver:  84
# step in driver:  85
# step in driver:  86
# step in driver:  87
# step in driver:  88
# step in driver:  89
# step in driver:  90
# step in driver:  91
# step in driver:  92
# step in driver:  93
# step in driver:  94
# step in driver:  95
# step in driver:  96
# step in driver:  97
# step in driver:  98
# step in driver:  99
# ──────────────────────────────────────────────────── Step 300 ─────────────────────────────────────────────────────
# train/action_mag 3.68 / train/action_max 3.68 / train/action_mean 0.56 / train/action_min -3.14 / train/action_std
# 0.99 / train/actor_opt_actor_opt_grad_overflow 0 / train/actor_opt_actor_opt_grad_scale 1e4 /
# train/actor_opt_grad_norm 7.3e-4 / train/actor_opt_grad_steps 20 / train/actor_opt_loss 29.41 / train/adv_mag
# 6.4e-3 / train/adv_max -5.9e-4 / train/adv_mean -3.8e-3 / train/adv_min -6.4e-3 / train/adv_std 1.8e-3 /
# train/cont_avg 0.99 / train/cont_loss_mean 0.05 / train/cont_loss_std 0.57 / train/cont_neg_acc 0 /
# train/cont_neg_loss 6.44 / train/cont_pos_acc 1 / train/cont_pos_loss 2.1e-3 / train/cont_pred 1 / train/cont_rate
# 0.99 / train/dyn_loss_mean 3.53 / train/dyn_loss_std 0.39 / train/extr_critic_critic_opt_critic_opt_grad_overflow 0
# / train/extr_critic_critic_opt_critic_opt_grad_scale 1e4 / train/extr_critic_critic_opt_grad_norm 19.94 /
# train/extr_critic_critic_opt_grad_steps 20 / train/extr_critic_critic_opt_loss 1e5 / train/extr_critic_mag 4e-5 /
# train/extr_critic_max -2.2e-5 / train/extr_critic_mean -3.6e-5 / train/extr_critic_min -4e-5 /
# train/extr_critic_std 1.8e-6 / train/extr_return_normed_mag 6e-3 / train/extr_return_normed_max -1.4e-4 /
# train/extr_return_normed_mean -3.4e-3 / train/extr_return_normed_min -6e-3 / train/extr_return_normed_std 1.8e-3 /
# train/extr_return_rate 0 / train/extr_return_raw_mag 6.4e-3 / train/extr_return_raw_max -6.2e-4 /
# train/extr_return_raw_mean -3.8e-3 / train/extr_return_raw_min -6.4e-3 / train/extr_return_raw_std 1.8e-3 /
# train/extr_reward_mag 6.2e-4 / train/extr_reward_max -5.3e-4 / train/extr_reward_mean -6e-4 / train/extr_reward_min
# -6.2e-4 / train/extr_reward_std 9.1e-6 / train/model_loss_mean 8.52 / train/model_loss_std 0.88 /
# train/model_opt_grad_norm 37.54 / train/model_opt_grad_steps 20 / train/model_opt_loss 8.5e4 /
# train/model_opt_model_opt_grad_overflow 0 / train/model_opt_model_opt_grad_scale 1e4 / train/policy_entropy_mag 2.8
# / train/policy_entropy_max 2.8 / train/policy_entropy_mean 2.68 / train/policy_entropy_min 2.12 /
# train/policy_entropy_std 0.06 / train/policy_logprob_mag 11.39 / train/policy_logprob_max -1.44 /
# train/policy_logprob_mean -2.69 / train/policy_logprob_min -11.39 / train/policy_logprob_std 1.03 /
# train/policy_randomness_mag 0.99 / train/policy_randomness_max 0.99 / train/policy_randomness_mean 0.97 /
# train/policy_randomness_min 0.85 / train/policy_randomness_std 0.01 / train/post_ent_mag 106.58 /
# train/post_ent_max 106.58 / train/post_ent_mean 106.44 / train/post_ent_min 106.31 / train/post_ent_std 0.06 /
# train/prior_ent_mag 108.39 / train/prior_ent_max 108.39 / train/prior_ent_mean 108.05 / train/prior_ent_min 107.67
# / train/prior_ent_std 0.13 / train/rep_loss_mean 3.53 / train/rep_loss_std 0.39 / train/reward_avg -0.01 /
# train/reward_loss_mean 4.86 / train/reward_loss_std 0.02 / train/reward_max_data 0.1 / train/reward_max_pred 5.6e-4
# / train/reward_neg_acc 1 / train/reward_neg_loss 4.86 / train/reward_pos_acc nan / train/reward_pos_loss nan /
# train/reward_pred -5.3e-4 / train/reward_rate 0 / train/vector_loss_mean 1.49 / train/vector_loss_std 0.52 /
# replay/size 293 / replay/inserts 30 / replay/samples 112 / replay/insert_wait_avg 5.2e-6 / replay/insert_wait_frac
# 1 / replay/sample_wait_avg 2e-6 / replay/sample_wait_frac 1 / timer/duration 150.38 / timer/env.step_count 30 /
# timer/env.step_total 142.32 / timer/env.step_frac 0.95 / timer/env.step_avg 4.74 / timer/env.step_min 4.64 /
# timer/env.step_max 4.81 / timer/replay.add_count 30 / timer/replay.add_total 9.8e-3 / timer/replay.add_frac 6.5e-5
# / timer/replay.add_avg 3.3e-4 / timer/replay.add_min 1.7e-4 / timer/replay.add_max 6.6e-4 /
# timer/logger.write_count 1 / timer/logger.write_total 0.01 / timer/logger.write_frac 9.4e-5 /
# timer/logger.write_avg 0.01 / timer/logger.write_min 0.01 / timer/logger.write_max 0.01 /
# timer/checkpoint.save_count 0 / timer/checkpoint.save_total 0 / timer/checkpoint.save_frac 0 /
# timer/agent.save_count 0 / timer/agent.save_total 0 / timer/agent.save_frac 0 / timer/replay.save_count 0 /
# timer/replay.save_total 0 / timer/replay.save_frac 0 / timer/agent.policy_count 30 / timer/agent.policy_total 0.3 /
# timer/agent.policy_frac 2e-3 / timer/agent.policy_avg 1e-2 / timer/agent.policy_min 8.8e-3 / timer/agent.policy_max
# 0.01 / timer/dataset_count 7 / timer/dataset_total 8.7e-4 / timer/dataset_frac 5.8e-6 / timer/dataset_avg 1.2e-4 /
# timer/dataset_min 1.1e-4 / timer/dataset_max 1.6e-4 / timer/agent.train_count 7 / timer/agent.train_total 7.64 /
# timer/agent.train_frac 0.05 / timer/agent.train_avg 1.09 / timer/agent.train_min 1.06 / timer/agent.train_max 1.13
# / timer/agent.report_count 1 / timer/agent.report_total 0.07 / timer/agent.report_frac 4.9e-4 /
# timer/agent.report_avg 0.07 / timer/agent.report_min 0.07 / timer/agent.report_max 0.07 / fps 0.2
# step in driver:  0
# step in driver:  1
# step in driver:  2
# step in driver:  3
# step in driver:  4
# step in driver:  5
# step in driver:  6
# step in driver:  7
# step in driver:  8
# step in driver:  9
# step in driver:  10
# step in driver:  11
# step in driver:  12
# step in driver:  13
# step in driver:  14
# step in driver:  15
# step in driver:  16
# step in driver:  17
# step in driver:  18
# step in driver:  19
# step in driver:  20
# step in driver:  21
# step in driver:  22
# step in driver:  23
# step in driver:  24
# step in driver:  25
# step in driver:  26
# step in driver:  27
# step in driver:  28
# step in driver:  29
# ──────────────────────────────────────────────────── Step 330 ─────────────────────────────────────────────────────
# train/action_mag 4.19 / train/action_max 4.19 / train/action_mean 0.55 / train/action_min -3.46 / train/action_std
# 1 / train/actor_opt_actor_opt_grad_overflow 0 / train/actor_opt_actor_opt_grad_scale 1e4 /
# train/actor_opt_grad_norm 7e-4 / train/actor_opt_grad_steps 30 / train/actor_opt_loss 80.88 / train/adv_mag 0.02 /
# train/adv_max -1.4e-3 / train/adv_mean -9.1e-3 / train/adv_min -0.02 / train/adv_std 4.2e-3 / train/cont_avg 0.99 /
# train/cont_loss_mean 0.06 / train/cont_loss_std 0.66 / train/cont_neg_acc 0 / train/cont_neg_loss 7.51 /
# train/cont_pos_acc 1 / train/cont_pos_loss 1.3e-3 / train/cont_pred 1 / train/cont_rate 0.99 / train/dyn_loss_mean
# 1.39 / train/dyn_loss_std 0.19 / train/extr_critic_critic_opt_critic_opt_grad_overflow 0 /
# train/extr_critic_critic_opt_critic_opt_grad_scale 1e4 / train/extr_critic_critic_opt_grad_norm 21.35 /
# train/extr_critic_critic_opt_grad_steps 30 / train/extr_critic_critic_opt_loss 1e5 / train/extr_critic_mag 1.4e-4 /
# train/extr_critic_max -8.6e-5 / train/extr_critic_mean -1.3e-4 / train/extr_critic_min -1.4e-4 /
# train/extr_critic_std 5.2e-6 / train/extr_return_normed_mag 0.01 / train/extr_return_normed_max -8.7e-5 /
# train/extr_return_normed_mean -7.7e-3 / train/extr_return_normed_min -0.01 / train/extr_return_normed_std 4.2e-3 /
# train/extr_return_rate 0 / train/extr_return_raw_mag 0.02 / train/extr_return_raw_max -1.6e-3 /
# train/extr_return_raw_mean -9.2e-3 / train/extr_return_raw_min -0.02 / train/extr_return_raw_std 4.2e-3 /
# train/extr_reward_mag 1.5e-3 / train/extr_reward_max -1.3e-3 / train/extr_reward_mean -1.4e-3 /
# train/extr_reward_min -1.5e-3 / train/extr_reward_std 1.3e-5 / train/model_loss_mean 5.85 / train/model_loss_std
# 0.72 / train/model_opt_grad_norm 23.55 / train/model_opt_grad_steps 30 / train/model_opt_loss 5.8e4 /
# train/model_opt_model_opt_grad_overflow 0 / train/model_opt_model_opt_grad_scale 1e4 / train/policy_entropy_mag 2.8
# / train/policy_entropy_max 2.8 / train/policy_entropy_mean 2.72 / train/policy_entropy_min 2.36 /
# train/policy_entropy_std 0.05 / train/policy_logprob_mag 13.23 / train/policy_logprob_max -1.59 /
# train/policy_logprob_mean -2.72 / train/policy_logprob_min -13.23 / train/policy_logprob_std 1.01 /
# train/policy_randomness_mag 0.99 / train/policy_randomness_max 0.99 / train/policy_randomness_mean 0.97 /
# train/policy_randomness_min 0.9 / train/policy_randomness_std 0.01 / train/post_ent_mag 107.34 / train/post_ent_max
# 107.34 / train/post_ent_mean 107.24 / train/post_ent_min 107.14 / train/post_ent_std 0.05 / train/prior_ent_mag
# 107.96 / train/prior_ent_max 107.96 / train/prior_ent_mean 107.63 / train/prior_ent_min 107.27 /
# train/prior_ent_std 0.17 / train/rep_loss_mean 1.39 / train/rep_loss_std 0.19 / train/reward_avg -0.02 /
# train/reward_loss_mean 4.35 / train/reward_loss_std 0.02 / train/reward_max_data 0.1 / train/reward_max_pred 1.3e-3
# / train/reward_neg_acc 1 / train/reward_neg_loss 4.35 / train/reward_pos_acc nan / train/reward_pos_loss nan /
# train/reward_pred -1.3e-3 / train/reward_rate 0 / train/vector_loss_mean 0.6 / train/vector_loss_std 0.23 /
# replay/size 323 / replay/inserts 30 / replay/samples 128 / replay/insert_wait_avg 7.1e-6 / replay/insert_wait_frac
# 1 / replay/sample_wait_avg 2.1e-6 / replay/sample_wait_frac 1 / timer/duration 150.8 / timer/env.step_count 30 /
# timer/env.step_total 141.57 / timer/env.step_frac 0.94 / timer/env.step_avg 4.72 / timer/env.step_min 4.65 /
# timer/env.step_max 4.95 / timer/replay.add_count 30 / timer/replay.add_total 0.01 / timer/replay.add_frac 7e-5 /
# timer/replay.add_avg 3.5e-4 / timer/replay.add_min 2.2e-4 / timer/replay.add_max 4.3e-4 / timer/logger.write_count
# 1 / timer/logger.write_total 0.02 / timer/logger.write_frac 1.3e-4 / timer/logger.write_avg 0.02 /
# timer/logger.write_min 0.02 / timer/logger.write_max 0.02 / timer/checkpoint.save_count 0 /
# timer/checkpoint.save_total 0 / timer/checkpoint.save_frac 0 / timer/agent.save_count 0 / timer/agent.save_total 0
# / timer/agent.save_frac 0 / timer/replay.save_count 0 / timer/replay.save_total 0 / timer/replay.save_frac 0 /
# timer/agent.policy_count 30 / timer/agent.policy_total 0.29 / timer/agent.policy_frac 1.9e-3 /
# timer/agent.policy_avg 9.6e-3 / timer/agent.policy_min 8.4e-3 / timer/agent.policy_max 0.02 / timer/dataset_count 8
# / timer/dataset_total 9.2e-4 / timer/dataset_frac 6.1e-6 / timer/dataset_avg 1.1e-4 / timer/dataset_min 8.4e-5 /
# timer/dataset_max 1.6e-4 / timer/agent.train_count 8 / timer/agent.train_total 8.83 / timer/agent.train_frac 0.06 /
# timer/agent.train_avg 1.1 / timer/agent.train_min 1.04 / timer/agent.train_max 1.25 / timer/agent.report_count 1 /
# timer/agent.report_total 0.07 / timer/agent.report_frac 4.4e-4 / timer/agent.report_avg 0.07 /
# timer/agent.report_min 0.07 / timer/agent.report_max 0.07 / fps 0.2
# step in driver:  30
# step in driver:  31
# step in driver:  32
# step in driver:  33
# step in driver:  34
# step in driver:  35
# step in driver:  36
# step in driver:  37
# step in driver:  38
# step in driver:  39
# step in driver:  40
# step in driver:  41
# step in driver:  42
# step in driver:  43
# step in driver:  44
# step in driver:  45
# step in driver:  46
# step in driver:  47
# step in driver:  48
# step in driver:  49
# step in driver:  50
# step in driver:  51
# step in driver:  52
# step in driver:  53
# step in driver:  54
# step in driver:  55
# step in driver:  56
# step in driver:  57
# step in driver:  58
# step in driver:  59
# ──────────────────────────────────────────────────── Step 360 ─────────────────────────────────────────────────────
# train/action_mag 4.14 / train/action_max 4.14 / train/action_mean 0.57 / train/action_min -3.29 / train/action_std
# 1 / train/actor_opt_actor_opt_grad_overflow 0 / train/actor_opt_actor_opt_grad_scale 1e4 /
# train/actor_opt_grad_norm 5.9e-4 / train/actor_opt_grad_steps 40 / train/actor_opt_loss 179.55 / train/adv_mag 0.03
# / train/adv_max -3e-3 / train/adv_mean -0.02 / train/adv_min -0.03 / train/adv_std 8.9e-3 / train/cont_avg 0.99 /
# train/cont_loss_mean 0.05 / train/cont_loss_std 0.5 / train/cont_neg_acc 0 / train/cont_neg_loss 5.72 /
# train/cont_pos_acc 1 / train/cont_pos_loss 1.2e-3 / train/cont_pred 1 / train/cont_rate 0.99 / train/dyn_loss_mean
# 1 / train/dyn_loss_std 1.1e-3 / train/extr_critic_critic_opt_critic_opt_grad_overflow 0 /
# train/extr_critic_critic_opt_critic_opt_grad_scale 1e4 / train/extr_critic_critic_opt_grad_norm 21.67 /
# train/extr_critic_critic_opt_grad_steps 40 / train/extr_critic_critic_opt_loss 9.8e4 / train/extr_critic_mag 2.8e-4
# / train/extr_critic_max -2e-4 / train/extr_critic_mean -2.7e-4 / train/extr_critic_min -2.8e-4 /
# train/extr_critic_std 7.9e-6 / train/extr_return_normed_mag 0.03 / train/extr_return_normed_max 3.2e-4 /
# train/extr_return_normed_mean -0.02 / train/extr_return_normed_min -0.03 / train/extr_return_normed_std 8.9e-3 /
# train/extr_return_rate 0 / train/extr_return_raw_mag 0.03 / train/extr_return_raw_max -3.3e-3 /
# train/extr_return_raw_mean -0.02 / train/extr_return_raw_min -0.03 / train/extr_return_raw_std 8.9e-3 /
# train/extr_reward_mag 3.1e-3 / train/extr_reward_max -2.9e-3 / train/extr_reward_mean -3e-3 / train/extr_reward_min
# -3.1e-3 / train/extr_reward_std 1.7e-5 / train/model_loss_mean 4.81 / train/model_loss_std 0.55 /
# train/model_opt_grad_norm 17.54 / train/model_opt_grad_steps 40 / train/model_opt_loss 4.8e4 /
# train/model_opt_model_opt_grad_overflow 0 / train/model_opt_model_opt_grad_scale 1e4 / train/policy_entropy_mag
# 2.81 / train/policy_entropy_max 2.81 / train/policy_entropy_mean 2.75 / train/policy_entropy_min 2.43 /
# train/policy_entropy_std 0.03 / train/policy_logprob_mag 11.54 / train/policy_logprob_max -1.69 /
# train/policy_logprob_mean -2.75 / train/policy_logprob_min -11.54 / train/policy_logprob_std 0.99 /
# train/policy_randomness_mag 0.99 / train/policy_randomness_max 0.99 / train/policy_randomness_mean 0.98 /
# train/policy_randomness_min 0.91 / train/policy_randomness_std 6.9e-3 / train/post_ent_mag 107.56 /
# train/post_ent_max 107.56 / train/post_ent_mean 107.46 / train/post_ent_min 107.32 / train/post_ent_std 0.05 /
# train/prior_ent_mag 107.27 / train/prior_ent_max 107.27 / train/prior_ent_mean 106.99 / train/prior_ent_min 106.67
# / train/prior_ent_std 0.16 / train/rep_loss_mean 1 / train/rep_loss_std 1.1e-3 / train/reward_avg -0.01 /
# train/reward_loss_mean 3.8 / train/reward_loss_std 0.02 / train/reward_max_data 0.1 / train/reward_max_pred 2.8e-3
# / train/reward_neg_acc 1 / train/reward_neg_loss 3.8 / train/reward_pos_acc nan / train/reward_pos_loss nan /
# train/reward_pred -2.8e-3 / train/reward_rate 0 / train/vector_loss_mean 0.36 / train/vector_loss_std 0.16 /
# replay/size 353 / replay/inserts 30 / replay/samples 112 / replay/insert_wait_avg 6.5e-6 / replay/insert_wait_frac
# 1 / replay/sample_wait_avg 1.6e-6 / replay/sample_wait_frac 1 / timer/duration 149.9 / timer/env.step_count 30 /
# timer/env.step_total 141.72 / timer/env.step_frac 0.95 / timer/env.step_avg 4.72 / timer/env.step_min 4.64 /
# timer/env.step_max 4.9 / timer/replay.add_count 30 / timer/replay.add_total 9.5e-3 / timer/replay.add_frac 6.4e-5 /
# timer/replay.add_avg 3.2e-4 / timer/replay.add_min 1.7e-4 / timer/replay.add_max 4.6e-4 / timer/logger.write_count
# 1 / timer/logger.write_total 0.02 / timer/logger.write_frac 1.3e-4 / timer/logger.write_avg 0.02 /
# timer/logger.write_min 0.02 / timer/logger.write_max 0.02 / timer/checkpoint.save_count 0 /
# timer/checkpoint.save_total 0 / timer/checkpoint.save_frac 0 / timer/agent.save_count 0 / timer/agent.save_total 0
# / timer/agent.save_frac 0 / timer/replay.save_count 0 / timer/replay.save_total 0 / timer/replay.save_frac 0 /
# timer/agent.policy_count 30 / timer/agent.policy_total 0.31 / timer/agent.policy_frac 2.1e-3 /
# timer/agent.policy_avg 0.01 / timer/agent.policy_min 8.9e-3 / timer/agent.policy_max 0.01 / timer/dataset_count 7 /
# timer/dataset_total 8.5e-4 / timer/dataset_frac 5.7e-6 / timer/dataset_avg 1.2e-4 / timer/dataset_min 9.3e-5 /
# timer/dataset_max 1.5e-4 / timer/agent.train_count 7 / timer/agent.train_total 7.74 / timer/agent.train_frac 0.05 /
# timer/agent.train_avg 1.11 / timer/agent.train_min 1.02 / timer/agent.train_max 1.19 / timer/agent.report_count 1 /
# timer/agent.report_total 0.08 / timer/agent.report_frac 5.2e-4 / timer/agent.report_avg 0.08 /
# timer/agent.report_min 0.08 / timer/agent.report_max 0.08 / fps 0.2
# step in driver:  60
# step in driver:  61
# step in driver:  62
# step in driver:  63
# step in driver:  64
# step in driver:  65
# step in driver:  66
# step in driver:  67
# step in driver:  68
# step in driver:  69
# step in driver:  70
# step in driver:  71
# step in driver:  72
# step in driver:  73
# step in driver:  74
# step in driver:  75
# step in driver:  76
# step in driver:  77
# step in driver:  78
# step in driver:  79
# step in driver:  80
# step in driver:  81
# step in driver:  82
# step in driver:  83
# step in driver:  84
# step in driver:  85
# step in driver:  86
# step in driver:  87
# step in driver:  88
# step in driver:  89
# ──────────────────────────────────────────────────── Step 390 ─────────────────────────────────────────────────────
# report/cont_avg 1 / report/cont_loss_mean 1.3e-3 / report/cont_loss_std 9.5e-4 / report/cont_neg_acc nan /
# report/cont_neg_loss nan / report/cont_pos_acc 1 / report/cont_pos_loss 1.3e-3 / report/cont_pred 1 /
# report/cont_rate 1 / report/dyn_loss_mean 1 / report/dyn_loss_std 2.9e-4 / report/model_loss_mean 4.15 /
# report/model_loss_std 0.11 / report/post_ent_mag 107.41 / report/post_ent_max 107.41 / report/post_ent_mean 107.32
# / report/post_ent_min 107.22 / report/post_ent_std 0.05 / report/prior_ent_mag 106.92 / report/prior_ent_max 106.92
# / report/prior_ent_mean 106.63 / report/prior_ent_min 106.35 / report/prior_ent_std 0.15 / report/rep_loss_mean 1 /
# report/rep_loss_std 2.9e-4 / report/reward_avg -0.02 / report/reward_loss_mean 3.28 / report/reward_loss_std 0.02 /
# report/reward_max_data 0.1 / report/reward_max_pred 5.2e-3 / report/reward_neg_acc 1 / report/reward_neg_loss 3.28
# / report/reward_pos_acc nan / report/reward_pos_loss nan / report/reward_pred -5.1e-3 / report/reward_rate 0 /
# report/vector_loss_mean 0.27 / report/vector_loss_std 0.11 / replay/size 383 / replay/inserts 30 / replay/samples
# 128 / replay/insert_wait_avg 5.4e-6 / replay/insert_wait_frac 1 / replay/sample_wait_avg 1.7e-6 /
# replay/sample_wait_frac 1 / timer/duration 157.26 / timer/env.step_count 30 / timer/env.step_total 147.87 /
# timer/env.step_frac 0.94 / timer/env.step_avg 4.93 / timer/env.step_min 4.67 / timer/env.step_max 6.39 /
# timer/replay.add_count 30 / timer/replay.add_total 9.5e-3 / timer/replay.add_frac 6.1e-5 / timer/replay.add_avg
# 3.2e-4 / timer/replay.add_min 1.5e-4 / timer/replay.add_max 6.1e-4 / timer/logger.write_count 1 /
# timer/logger.write_total 0.02 / timer/logger.write_frac 1.2e-4 / timer/logger.write_avg 0.02 /
# timer/logger.write_min 0.02 / timer/logger.write_max 0.02 / timer/checkpoint.save_count 0 /
# timer/checkpoint.save_total 0 / timer/checkpoint.save_frac 0 / timer/agent.save_count 0 / timer/agent.save_total 0
# / timer/agent.save_frac 0 / timer/replay.save_count 0 / timer/replay.save_total 0 / timer/replay.save_frac 0 /
# timer/agent.policy_count 30 / timer/agent.policy_total 0.28 / timer/agent.policy_frac 1.8e-3 /
# timer/agent.policy_avg 9.2e-3 / timer/agent.policy_min 8.4e-3 / timer/agent.policy_max 0.01 / timer/dataset_count 8
# / timer/dataset_total 7.5e-4 / timer/dataset_frac 4.8e-6 / timer/dataset_avg 9.4e-5 / timer/dataset_min 7.9e-5 /
# timer/dataset_max 1.3e-4 / timer/agent.train_count 8 / timer/agent.train_total 9 / timer/agent.train_frac 0.06 /
# timer/agent.train_avg 1.13 / timer/agent.train_min 1.05 / timer/agent.train_max 1.16 / timer/agent.report_count 1 /
# timer/agent.report_total 0.06 / timer/agent.report_frac 4e-4 / timer/agent.report_avg 0.06 / timer/agent.report_min
# 0.06 / timer/agent.report_max 0.06 / fps 0.19
# step in driver:  90
# step in driver:  91
# step in driver:  92
# step in driver:  93
# step in driver:  94
# step in driver:  95
# step in driver:  96
# step in driver:  97
# step in driver:  98
# step in driver:  99
# Writing checkpoint: /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/logdir/notebook_test_cyl_ks_9/checkpoint.ckpt
# step in driver:  0
# Saved chunk: 20240605T131009F949854-6E0KALu1rwKCBGMJmfv1Ji-0000000000000000000000-400.npz
# Wrote checkpoint: /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/logdir/notebook_test_cyl_ks_9/checkpoint.ckpt
# step in driver:  1
# Episode has 200 steps and return -4.0.
# step in driver:  2
# Mean accumulated drag on the whole episode: -0.7352850017020578
# Number of probes: 64
# test cwd env:  /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer
# Simulated 49 iterations before starting the control
# step in driver:  3
# step in driver:  4
# step in driver:  5
# step in driver:  6
# step in driver:  7
# step in driver:  8
# step in driver:  9
# step in driver:  10
# step in driver:  11
# step in driver:  12
# step in driver:  13
# step in driver:  14
# step in driver:  15
# step in driver:  16
# step in driver:  17
# step in driver:  18
# step in driver:  19
# ──────────────────────────────────────────────────── Step 420 ─────────────────────────────────────────────────────
# episode/length 200 / episode/score -3.97 / episode/sum_abs_reward 4.02 / episode/reward_rate 0 / train/action_mag
# 4.34 / train/action_max 4.34 / train/action_mean 0.53 / train/action_min -3.41 / train/action_std 1.02 /
# train/actor_opt_actor_opt_grad_overflow 0 / train/actor_opt_actor_opt_grad_scale 1e4 / train/actor_opt_grad_norm
# 6.3e-4 / train/actor_opt_grad_steps 50 / train/actor_opt_loss 352.87 / train/adv_mag 0.06 / train/adv_max -5.8e-3 /
# train/adv_mean -0.04 / train/adv_min -0.06 / train/adv_std 0.02 / train/cont_avg 0.99 / train/cont_loss_mean 0.05 /
# train/cont_loss_std 0.53 / train/cont_neg_acc 0 / train/cont_neg_loss 6.02 / train/cont_pos_acc 1 /
# train/cont_pos_loss 1.1e-3 / train/cont_pred 1 / train/cont_rate 0.99 / train/dyn_loss_mean 1 / train/dyn_loss_std
# 1e-3 / train/extr_critic_critic_opt_critic_opt_grad_overflow 0 / train/extr_critic_critic_opt_critic_opt_grad_scale
# 1e4 / train/extr_critic_critic_opt_grad_norm 21.07 / train/extr_critic_critic_opt_grad_steps 50 /
# train/extr_critic_critic_opt_loss 9.5e4 / train/extr_critic_mag 4.7e-4 / train/extr_critic_max -3.5e-4 /
# train/extr_critic_mean -4.5e-4 / train/extr_critic_min -4.7e-4 / train/extr_critic_std 1.1e-5 /
# train/extr_return_normed_mag 0.05 / train/extr_return_normed_max 1.5e-3 / train/extr_return_normed_mean -0.03 /
# train/extr_return_normed_min -0.05 / train/extr_return_normed_std 0.02 / train/extr_return_rate 0 /
# train/extr_return_raw_mag 0.06 / train/extr_return_raw_max -6.3e-3 / train/extr_return_raw_mean -0.04 /
# train/extr_return_raw_min -0.06 / train/extr_return_raw_std 0.02 / train/extr_reward_mag 5.9e-3 /
# train/extr_reward_max -5.6e-3 / train/extr_reward_mean -5.8e-3 / train/extr_reward_min -5.9e-3 /
# train/extr_reward_std 2.3e-5 / train/model_loss_mean 4.15 / train/model_loss_std 0.56 / train/model_opt_grad_norm
# 14.17 / train/model_opt_grad_steps 50 / train/model_opt_loss 4.1e4 / train/model_opt_model_opt_grad_overflow 0 /
# train/model_opt_model_opt_grad_scale 1e4 / train/policy_entropy_mag 2.81 / train/policy_entropy_max 2.81 /
# train/policy_entropy_mean 2.77 / train/policy_entropy_min 2.6 / train/policy_entropy_std 0.03 /
# train/policy_logprob_mag 8.44 / train/policy_logprob_max -1.72 / train/policy_logprob_mean -2.76 /
# train/policy_logprob_min -8.44 / train/policy_logprob_std 0.97 / train/policy_randomness_mag 0.99 /
# train/policy_randomness_max 0.99 / train/policy_randomness_mean 0.98 / train/policy_randomness_min 0.95 /
# train/policy_randomness_std 5.6e-3 / train/post_ent_mag 107.4 / train/post_ent_max 107.4 / train/post_ent_mean
# 107.3 / train/post_ent_min 107.22 / train/post_ent_std 0.05 / train/prior_ent_mag 106.9 / train/prior_ent_max 106.9
# / train/prior_ent_mean 106.63 / train/prior_ent_min 106.22 / train/prior_ent_std 0.15 / train/rep_loss_mean 1 /
# train/rep_loss_std 1e-3 / train/reward_avg -0.02 / train/reward_loss_mean 3.23 / train/reward_loss_std 0.02 /
# train/reward_max_data 0.1 / train/reward_max_pred 5.5e-3 / train/reward_neg_acc 1 / train/reward_neg_loss 3.23 /
# train/reward_pos_acc nan / train/reward_pos_loss nan / train/reward_pred -5.4e-3 / train/reward_rate 0 /
# ...
# 1.04 / timer/agent.train_max 1.16 / timer/agent.report_count 1 / timer/agent.report_total 0.07 /
# timer/agent.report_frac 4.9e-4 / timer/agent.report_avg 0.07 / timer/agent.report_min 0.07 / timer/agent.report_max
# 0.07 / fps 0.2
# step in driver:  70
# step in driver:  71
# step in driver:  72
# step in driver:  73
# step in driver:  74
# step in driver:  75
# step in driver:  76
# step in driver:  77
# step in driver:  78
# step in driver:  79
# step in driver:  80
# step in driver:  81
# step in driver:  82
# step in driver:  83
# step in driver:  84
# step in driver:  85
# step in driver:  86
# step in driver:  87
# step in driver:  88
# step in driver:  89
# step in driver:  90
# step in driver:  91
# step in driver:  92
# step in driver:  93
# step in driver:  94
# step in driver:  95
# step in driver:  96
# step in driver:  97
# step in driver:  98
# step in driver:  99
# ──────────────────────────────────────────────────── Step 600 ─────────────────────────────────────────────────────
# train/action_mag 4.38 / train/action_max 4.08 / train/action_mean 0.05 / train/action_min -4.38 / train/action_std
# 1.3 / train/actor_opt_actor_opt_grad_overflow 0 / train/actor_opt_actor_opt_grad_scale 1e4 /
# train/actor_opt_grad_norm 2.6e-4 / train/actor_opt_grad_steps 100 / train/actor_opt_loss 1233.72 / train/adv_mag
# 0.21 / train/adv_max -0.02 / train/adv_mean -0.13 / train/adv_min -0.21 / train/adv_std 0.06 / train/cont_avg 1 /
# train/cont_loss_mean 3.8e-3 / train/cont_loss_std 1.5e-3 / train/cont_neg_acc nan / train/cont_neg_loss nan /
# train/cont_pos_acc 1 / train/cont_pos_loss 3.8e-3 / train/cont_pred 1 / train/cont_rate 1 / train/dyn_loss_mean 1 /
# train/dyn_loss_std 0 / train/extr_critic_critic_opt_critic_opt_grad_overflow 0 /
# train/extr_critic_critic_opt_critic_opt_grad_scale 1e4 / train/extr_critic_critic_opt_grad_norm 18.25 /
# train/extr_critic_critic_opt_grad_steps 100 / train/extr_critic_critic_opt_loss 7.8e4 / train/extr_critic_mag
# 3.5e-3 / train/extr_critic_max -3.1e-3 / train/extr_critic_mean -3.4e-3 / train/extr_critic_min -3.5e-3 /
# train/extr_critic_std 4.3e-5 / train/extr_return_normed_mag 0.14 / train/extr_return_normed_max 0.05 /
# train/extr_return_normed_mean -0.05 / train/extr_return_normed_min -0.14 / train/extr_return_normed_std 0.06 /
# train/extr_return_rate 0 / train/extr_return_raw_mag 0.21 / train/extr_return_raw_max -0.02 /
# train/extr_return_raw_mean -0.13 / train/extr_return_raw_min -0.21 / train/extr_return_raw_std 0.06 /
# train/extr_reward_mag 0.02 / train/extr_reward_max -0.02 / train/extr_reward_mean -0.02 / train/extr_reward_min
# -0.02 / train/extr_reward_std 2.3e-5 / train/model_loss_mean 1.81 / train/model_loss_std 0.15 /
# train/model_opt_grad_norm 8.32 / train/model_opt_grad_steps 100 / train/model_opt_loss 1.8e4 /
# train/model_opt_model_opt_grad_overflow 0 / train/model_opt_model_opt_grad_scale 1e4 / train/policy_entropy_mag
# 2.83 / train/policy_entropy_max 2.83 / train/policy_entropy_mean 2.81 / train/policy_entropy_min 2.71 /
# train/policy_entropy_std 0.01 / train/policy_logprob_mag 8.72 / train/policy_logprob_max -1.79 /
# train/policy_logprob_mean -2.8 / train/policy_logprob_min -8.72 / train/policy_logprob_std 0.97 /
# train/policy_randomness_mag 1 / train/policy_randomness_max 1 / train/policy_randomness_mean 0.99 /
# train/policy_randomness_min 0.97 / train/policy_randomness_std 2.6e-3 / train/post_ent_mag 106.21 /
# train/post_ent_max 106.21 / train/post_ent_mean 106.1 / train/post_ent_min 105.98 / train/post_ent_std 0.05 /
# train/prior_ent_mag 106.56 / train/prior_ent_max 106.56 / train/prior_ent_mean 106.37 / train/prior_ent_min 106.17
# / train/prior_ent_std 0.1 / train/rep_loss_mean 1 / train/rep_loss_std 0 / train/reward_avg -0.02 /
# train/reward_loss_mean 1.06 / train/reward_loss_std 0.12 / train/reward_max_data 0.09 / train/reward_max_pred 0.02
# / train/reward_neg_acc 1 / train/reward_neg_loss 1.06 / train/reward_pos_acc nan / train/reward_pos_loss nan /
# train/reward_pred -0.02 / train/reward_rate 0 / train/vector_loss_mean 0.15 / train/vector_loss_std 0.09 /
# replay/size 593 / replay/inserts 30 / replay/samples 112 / replay/insert_wait_avg 6.1e-6 / replay/insert_wait_frac
# 1 / replay/sample_wait_avg 1.7e-6 / replay/sample_wait_frac 1 / timer/duration 152.43 / timer/env.step_count 30 /
# timer/env.step_total 143.68 / timer/env.step_frac 0.94 / timer/env.step_avg 4.79 / timer/env.step_min 4.71 /
# timer/env.step_max 5.56 / timer/replay.add_count 30 / timer/replay.add_total 8.8e-3 / timer/replay.add_frac 5.8e-5
# / timer/replay.add_avg 2.9e-4 / timer/replay.add_min 1.6e-4 / timer/replay.add_max 4.2e-4 /
# timer/logger.write_count 1 / timer/logger.write_total 0.02 / timer/logger.write_frac 1.2e-4 /
# timer/logger.write_avg 0.02 / timer/logger.write_min 0.02 / timer/logger.write_max 0.02 /
# timer/checkpoint.save_count 0 / timer/checkpoint.save_total 0 / timer/checkpoint.save_frac 0 /
# timer/agent.save_count 0 / timer/agent.save_total 0 / timer/agent.save_frac 0 / timer/replay.save_count 0 /
# timer/replay.save_total 0 / timer/replay.save_frac 0 / timer/agent.policy_count 30 / timer/agent.policy_total 0.58
# / timer/agent.policy_frac 3.8e-3 / timer/agent.policy_avg 0.02 / timer/agent.policy_min 8.7e-3 /
# timer/agent.policy_max 0.31 / timer/dataset_count 7 / timer/dataset_total 6.1e-4 / timer/dataset_frac 4e-6 /
# timer/dataset_avg 8.7e-5 / timer/dataset_min 7.2e-5 / timer/dataset_max 1.3e-4 / timer/agent.train_count 7 /
# timer/agent.train_total 8.06 / timer/agent.train_frac 0.05 / timer/agent.train_avg 1.15 / timer/agent.train_min
# 1.05 / timer/agent.train_max 1.47 / timer/agent.report_count 1 / timer/agent.report_total 0.07 /
# timer/agent.report_frac 4.7e-4 / timer/agent.report_avg 0.07 / timer/agent.report_min 0.07 / timer/agent.report_max
# 0.07 / fps 0.2
# Writing checkpoint: /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/logdir/notebook_test_cyl_ks_9/checkpoint.ckpt
# step in driver:  0
# Saved chunk: 20240605T131009F949854-6E0KALu1rwKCBGMJmfv1Ji-0000000000000000000000-600.npz
# Wrote checkpoint: /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/logdir/notebook_test_cyl_ks_9/checkpoint.ckpt
# step in driver:  1
# step in driver:  2
# Episode has 200 steps and return -4.5.
# step in driver:  3
# Mean accumulated drag on the whole episode: -0.7281672769728784
# Number of probes: 64
# test cwd env:  /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer
# Simulated 392 iterations before starting the control
# step in driver:  4
# step in driver:  5
# step in driver:  6
# step in driver:  7
# step in driver:  8
# step in driver:  9
# step in driver:  10
# step in driver:  11
# step in driver:  12
# step in driver:  13
# step in driver:  14
# step in driver:  15
# step in driver:  16
# step in driver:  17
# step in driver:  18
# step in driver:  19
# step in driver:  20
# step in driver:  21
# step in driver:  22
# step in driver:  23
# step in driver:  24
# step in driver:  25
# step in driver:  26
# step in driver:  27
# step in driver:  28
# step in driver:  29
# ──────────────────────────────────────────────────── Step 630 ─────────────────────────────────────────────────────
# episode/length 200 / episode/score -4.55 / episode/sum_abs_reward 4.72 / episode/reward_rate 0 /
# stats/mean_log_entropy 2.78 / report/cont_avg 0.99 / report/cont_loss_mean 0.05 / report/cont_loss_std 0.5 /
# report/cont_neg_acc 0 / report/cont_neg_loss 5.73 / report/cont_pos_acc 1 / report/cont_pos_loss 3.7e-3 /
# report/cont_pred 1 / report/cont_rate 0.99 / report/dyn_loss_mean 1 / report/dyn_loss_std 9.7e-4 /
# report/model_loss_mean 1.67 / report/model_loss_std 0.55 / report/post_ent_mag 106 / report/post_ent_max 106 /
# report/post_ent_mean 105.9 / report/post_ent_min 105.81 / report/post_ent_std 0.04 / report/prior_ent_mag 106.59 /
# report/prior_ent_max 106.59 / report/prior_ent_mean 106.36 / report/prior_ent_min 106.1 / report/prior_ent_std 0.11
# / report/rep_loss_mean 1 / report/rep_loss_std 9.7e-4 / report/reward_avg -0.02 / report/reward_loss_mean 0.88 /
# report/reward_loss_std 0.15 / report/reward_max_data 0.13 / report/reward_max_pred 0.02 / report/reward_neg_acc 1 /
# report/reward_neg_loss 0.88 / report/reward_pos_acc nan / report/reward_pos_loss nan / report/reward_pred -0.02 /
# report/reward_rate 0 / report/vector_loss_mean 0.14 / report/vector_loss_std 0.07 / replay/size 623 /
# replay/inserts 30 / replay/samples 128 / replay/insert_wait_avg 5.8e-6 / replay/insert_wait_frac 1 /
# replay/sample_wait_avg 1.5e-6 / replay/sample_wait_frac 1 / timer/duration 174.44 / timer/env.step_count 30 /
# timer/env.step_total 165.32 / timer/env.step_frac 0.95 / timer/env.step_avg 5.51 / timer/env.step_min 4.71 /
# timer/env.step_max 26.57 / timer/replay.add_count 30 / timer/replay.add_total 9.2e-3 / timer/replay.add_frac 5.3e-5
# / timer/replay.add_avg 3.1e-4 / timer/replay.add_min 1.5e-4 / timer/replay.add_max 4.1e-4 /
# timer/logger.write_count 1 / timer/logger.write_total 0.02 / timer/logger.write_frac 1.1e-4 /
# timer/logger.write_avg 0.02 / timer/logger.write_min 0.02 / timer/logger.write_max 0.02 /
# timer/checkpoint.save_count 1 / timer/checkpoint.save_total 1.1e-4 / timer/checkpoint.save_frac 6.4e-7 /
# timer/checkpoint.save_avg 1.1e-4 / timer/checkpoint.save_min 1.1e-4 / timer/checkpoint.save_max 1.1e-4 /
# timer/agent.save_count 1 / timer/agent.save_total 0.04 / timer/agent.save_frac 2.3e-4 / timer/agent.save_avg 0.04 /
# timer/agent.save_min 0.04 / timer/agent.save_max 0.04 / timer/replay.save_count 1 / timer/replay.save_total 6.5e-5
# / timer/replay.save_frac 3.7e-7 / timer/replay.save_avg 6.5e-5 / timer/replay.save_min 6.5e-5 /
# timer/replay.save_max 6.5e-5 / timer/agent.policy_count 30 / timer/agent.policy_total 0.29 /
# timer/agent.policy_frac 1.7e-3 / timer/agent.policy_avg 9.8e-3 / timer/agent.policy_min 8.3e-3 /
# timer/agent.policy_max 0.01 / timer/dataset_count 8 / timer/dataset_total 7.6e-4 / timer/dataset_frac 4.4e-6 /
# timer/dataset_avg 9.5e-5 / timer/dataset_min 6.7e-5 / timer/dataset_max 1.2e-4 / timer/agent.train_count 8 /
# timer/agent.train_total 8.71 / timer/agent.train_frac 0.05 / timer/agent.train_avg 1.09 / timer/agent.train_min
# 1.03 / timer/agent.train_max 1.13 / timer/agent.report_count 1 / timer/agent.report_total 0.07 /
# timer/agent.report_frac 4e-4 / timer/agent.report_avg 0.07 / timer/agent.report_min 0.07 / timer/agent.report_max
# 0.07 / fps 0.17
# step in driver:  30
# step in driver:  31
# step in driver:  32
# step in driver:  33
# step in driver:  34
# step in driver:  35
# step in driver:  36
# step in driver:  37
# step in driver:  38
# step in driver:  39
# step in driver:  40
# step in driver:  41
# step in driver:  42
# step in driver:  43
# step in driver:  44
# step in driver:  45
# step in driver:  46
# step in driver:  47
# step in driver:  48
# step in driver:  49
# step in driver:  50
# step in driver:  51
# step in driver:  52
# step in driver:  53
# step in driver:  54
# step in driver:  55
# step in driver:  56
# step in driver:  57
# step in driver:  58
# step in driver:  59
# ──────────────────────────────────────────────────── Step 660 ─────────────────────────────────────────────────────
# train/action_mag 4.03 / train/action_max 4.03 / train/action_mean 0.01 / train/action_min -3.89 / train/action_std
# 1.35 / train/actor_opt_actor_opt_grad_overflow 0 / train/actor_opt_actor_opt_grad_scale 1e4 /
# train/actor_opt_grad_norm 1.8e-4 / train/actor_opt_grad_steps 110 / train/actor_opt_loss 1117.1 / train/adv_mag
# 0.19 / train/adv_max -0.02 / train/adv_mean -0.12 / train/adv_min -0.19 / train/adv_std 0.05 / train/cont_avg 0.99
# / train/cont_loss_mean 0.05 / train/cont_loss_std 0.55 / train/cont_neg_acc 0 / train/cont_neg_loss 6.29 /
# train/cont_pos_acc 1 / train/cont_pos_loss 3.6e-3 / train/cont_pred 1 / train/cont_rate 0.99 / train/dyn_loss_mean
# 1 / train/dyn_loss_std 5.3e-4 / train/extr_critic_critic_opt_critic_opt_grad_overflow 0 /
# train/extr_critic_critic_opt_critic_opt_grad_scale 1e4 / train/extr_critic_critic_opt_grad_norm 18.72 /
# train/extr_critic_critic_opt_grad_steps 110 / train/extr_critic_critic_opt_loss 7.4e4 / train/extr_critic_mag
# 4.7e-3 / train/extr_critic_max -4.1e-3 / train/extr_critic_mean -4.6e-3 / train/extr_critic_min -4.7e-3 /
# train/extr_critic_std 5.3e-5 / train/extr_return_normed_mag 0.11 / train/extr_return_normed_max 0.07 /
# train/extr_return_normed_mean -0.03 / train/extr_return_normed_min -0.11 / train/extr_return_normed_std 0.05 /
# train/extr_return_rate 0 / train/extr_return_raw_mag 0.2 / train/extr_return_raw_max -0.02 /
# train/extr_return_raw_mean -0.12 / train/extr_return_raw_min -0.2 / train/extr_return_raw_std 0.05 /
# train/extr_reward_mag 0.02 / train/extr_reward_max -0.02 / train/extr_reward_mean -0.02 / train/extr_reward_min
# -0.02 / train/extr_reward_std 2e-5 / train/model_loss_mean 1.66 / train/model_loss_std 0.58 /
# train/model_opt_grad_norm 6.7 / train/model_opt_grad_steps 110 / train/model_opt_loss 1.7e4 /
# train/model_opt_model_opt_grad_overflow 0 / train/model_opt_model_opt_grad_scale 1e4 / train/policy_entropy_mag
# 2.83 / train/policy_entropy_max 2.83 / train/policy_entropy_mean 2.81 / train/policy_entropy_min 2.68 /
# train/policy_entropy_std 0.01 / train/policy_logprob_mag 10.44 / train/policy_logprob_max -1.72 /
# train/policy_logprob_mean -2.81 / train/policy_logprob_min -10.44 / train/policy_logprob_std 0.99 /
# train/policy_randomness_mag 1 / train/policy_randomness_max 1 / train/policy_randomness_mean 0.99 /
# train/policy_randomness_min 0.97 / train/policy_randomness_std 2.3e-3 / train/post_ent_mag 106.04 /
# train/post_ent_max 106.04 / train/post_ent_mean 105.88 / train/post_ent_min 105.76 / train/post_ent_std 0.06 /
# train/prior_ent_mag 106.57 / train/prior_ent_max 106.57 / train/prior_ent_mean 106.34 / train/prior_ent_min 106.05
# / train/prior_ent_std 0.11 / train/rep_loss_mean 1 / train/rep_loss_std 5.3e-4 / train/reward_avg -0.02 /
# train/reward_loss_mean 0.87 / train/reward_loss_std 0.19 / train/reward_max_data 0.13 / train/reward_max_pred 0.02
# / train/reward_neg_acc 1 / train/reward_neg_loss 0.87 / train/reward_pos_acc nan / train/reward_pos_loss nan /
# train/reward_pred -0.02 / train/reward_rate 0 / train/vector_loss_mean 0.14 / train/vector_loss_std 0.07 /
# replay/size 653 / replay/inserts 30 / replay/samples 112 / replay/insert_wait_avg 8.7e-6 / replay/insert_wait_frac
# 1 / replay/sample_wait_avg 1.7e-6 / replay/sample_wait_frac 1 / timer/duration 204.98 / timer/env.step_count 30 /
# timer/env.step_total 193.7 / timer/env.step_frac 0.94 / timer/env.step_avg 6.46 / timer/env.step_min 4.64 /
# timer/env.step_max 22.82 / timer/replay.add_count 30 / timer/replay.add_total 0.01 / timer/replay.add_frac 6.1e-5 /
# timer/replay.add_avg 4.2e-4 / timer/replay.add_min 1.7e-4 / timer/replay.add_max 2.5e-3 / timer/logger.write_count
# 1 / timer/logger.write_total 0.01 / timer/logger.write_frac 7.1e-5 / timer/logger.write_avg 0.01 /
# timer/logger.write_min 0.01 / timer/logger.write_max 0.01 / timer/checkpoint.save_count 0 /
# timer/checkpoint.save_total 0 / timer/checkpoint.save_frac 0 / timer/agent.save_count 0 / timer/agent.save_total 0
# / timer/agent.save_frac 0 / timer/replay.save_count 0 / timer/replay.save_total 0 / timer/replay.save_frac 0 /
# timer/agent.policy_count 30 / timer/agent.policy_total 0.64 / timer/agent.policy_frac 3.1e-3 /
# timer/agent.policy_avg 0.02 / timer/agent.policy_min 8.7e-3 / timer/agent.policy_max 0.14 / timer/dataset_count 7 /
# timer/dataset_total 8.6e-4 / timer/dataset_frac 4.2e-6 / timer/dataset_avg 1.2e-4 / timer/dataset_min 9.3e-5 /
# timer/dataset_max 1.8e-4 / timer/agent.train_count 7 / timer/agent.train_total 9.99 / timer/agent.train_frac 0.05 /
# timer/agent.train_avg 1.43 / timer/agent.train_min 1.03 / timer/agent.train_max 3.19 / timer/agent.report_count 1 /
# timer/agent.report_total 0.59 / timer/agent.report_frac 2.9e-3 / timer/agent.report_avg 0.59 /
# timer/agent.report_min 0.59 / timer/agent.report_max 0.59 / fps 0.15
# step in driver:  60
# step in driver:  61
# step in driver:  62
# step in driver:  63
# step in driver:  64
# KeyboardInterrupt
