# %%
import warnings
import dreamerv3
from dreamerv3 import embodied
warnings.filterwarnings('ignore', '.*truncated to dtype int32.*')

print("Reading config", flush =True)

# See configs.yaml for all options.
config = embodied.Config(dreamerv3.configs['defaults'])
config = config.update(dreamerv3.configs['medium'])
config = config.update({
  'logdir': '~/PhD_projects2/dreamer_flows/dreamer/logdir/ks_test_run_negreward_wl100',
  'run.train_ratio': 64,
  'run.log_every': 30,  # seconds
  'batch_size': 16,
#   'batch_length': 30,
  'jax.prealloc': False,
  'encoder.mlp_keys': 'vector',
  'decoder.mlp_keys': 'vector',
  'encoder.cnn_keys': '$^',
  'decoder.cnn_keys': '$^',
  'jax.platform': 'cpu',
  'wrapper.length': 0,
})
# config = embodied.Flags(config).parse()

logdir = embodied.Path(config.logdir)
step = embodied.Counter()
logger = embodied.Logger(step, [
  embodied.logger.TerminalOutput(),
  embodied.logger.JSONLOutput(logdir, 'metrics.jsonl'),
  embodied.logger.TensorBoardOutput(logdir),
  # embodied.logger.WandBOutput(logdir.name, config),
  # embodied.logger.MLFlowOutput(logdir.name),
])
# Out:
# Reading config

# %%
import gym
from embodied.envs import from_gym

from ks.KS_environment import KSenv
import numpy as np

env = KSenv(nu=0.08,
          actuator_locs=np.linspace(0.2, 2 * np.pi - 0.2, 7),#np.array([0.0, np.pi / 4, np.pi / 2, 3 * np.pi / 4]),
          # sensor_locs=np.array([0, 2 * np.pi, 64]),
          burn_in=100)

# %%
env = from_gym.FromGym(env, obs_key='vector')  # Or obs_key='vector'.
env = dreamerv3.wrap_env(env, config)
env = embodied.BatchEnv([env], parallel=False)

# %%
agent = dreamerv3.Agent(env.obs_space, env.act_space, step, config)
# Out:
# In agent: setting up world model
# Encoder CNN shapes: {}
# Encoder MLP shapes: {'vector': (64,)}
# Decoder CNN shapes: {}
# Decoder MLP shapes: {'vector': (64,)}
# CUDA backend failed to initialize: INTERNAL: no supported devices found for platform CUDA (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# JAX devices (1): [CpuDevice(id=0)]
# Policy devices: TFRT_CPU_0
# Train devices:  TFRT_CPU_0
# Tracing train function.
# embed shape:   (16, 64, 1024)
# embed shape:   (16, 64, 1024)
# Optimizer model_opt has 24,130,496 variables.
# Optimizer actor_opt has 2,142,734 variables.
# Optimizer critic_opt has 2,297,215 variables.

# %%
replay = embodied.replay.Uniform(
  config.batch_length, config.replay_size, logdir / 'replay')

args = embodied.Config(
  **config.run, logdir=config.logdir,
  batch_steps=config.batch_size * config.batch_length)

# %% [markdown]
# Train the Model

# %%
# embodied.run.train(agent, env, replay, logger, args)

# %% [markdown]
# Loading Checkpoint Model

# %%
checkpoint = embodied.Checkpoint()
checkpoint.agent = agent
checkpoint.load('logdir/ks_test_run_negreward_wl100/checkpoint.ckpt', keys=['agent'])
# Out:
# Loading checkpoint: logdir/ks_test_run_negreward_wl100/checkpoint.ckpt
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:3                                                                                    │
# │                                                                                                  │
# │   1 checkpoint = embodied.Checkpoint()                                                           │
# │   2 checkpoint.agent = agent                                                                     │
# │ ❱ 3 checkpoint.load('logdir/ks_test_run_negreward_wl100/checkpoint.ckpt', keys=['agent'])        │
# │   4                                                                                              │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/dreamerv3/embodied/core/checkpo │
# │ int.py:75 in load                                                                                │
# │                                                                                                  │
# │   72 │   assert self._filename or filename                                                       │
# │   73 │   filename = path.Path(filename or self._filename)                                        │
# │   74 │   self._log and print(f'Loading checkpoint: {filename}')                                  │
# │ ❱ 75 │   data = basics.unpack(filename.read('rb'))                                               │
# │   76 │   keys = tuple(data.keys() if keys is None else keys)                                     │
# │   77 │   for key in keys:                                                                        │
# │   78 │     if key.startswith('_'):                                                               │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/dreamerv3/embodied/core/path.py │
# │ :74 in read                                                                                      │
# │                                                                                                  │
# │    71                                                                                            │
# │    72   def read(self, mode='r'):                                                                │
# │    73 │   assert mode in 'r rb'.split(), mode                                                    │
# │ ❱  74 │   with self.open(mode) as f:                                                             │
# │    75 │     return f.read()                                                                      │
# │    76                                                                                            │
# │    77   def write(self, content, mode='w'):                                                      │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/contextlib.py:119 in     │
# │ __enter__                                                                                        │
# │                                                                                                  │
# │   116 │   │   # they are only needed for recreation, which is not possible anymore               │
# │   117 │   │   del self.args, self.kwds, self.func                                                │
# │   118 │   │   try:                                                                               │
# │ ❱ 119 │   │   │   return next(self.gen)                                                          │
# │   120 │   │   except StopIteration:                                                              │
# │   121 │   │   │   raise RuntimeError("generator didn't yield") from None                         │
# │   122                                                                                            │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/dreamerv3/embodied/core/path.py │
# │ :125 in open                                                                                     │
# │                                                                                                  │
# │   122                                                                                            │
# │   123   @contextlib.contextmanager                                                               │
# │   124   def open(self, mode='r'):                                                                │
# │ ❱ 125 │   with open(str(self), mode=mode) as f:                                                  │
# │   126 │     yield f                                                                              │
# │   127                                                                                            │
# │   128   def absolute(self):                                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# FileNotFoundError: [Errno 2] No such file or directory: 'logdir/ks_test_run_negreward_wl100/checkpoint.ckpt'

# %% [markdown]
# Evaluating model with the environment

# %%
policy = lambda *args: agent.policy(*args, mode='eval')

# %%
from embodied.core.basics import convert
import collections

#initializing actions

_acts = {k: convert(np.zeros((len(env),) + v.shape, v.dtype))
        for k, v in env.act_space.items()}
_acts['reset'] = np.ones(len(env), bool)
_eps = [collections.defaultdict(list) for _ in range(len(env))]
_state = None


print(_acts)
# Out:
# {'action': array([[0., 0., 0., 0., 0., 0., 0.]], dtype=float32), 'reset': array([ True])}

# %%
from tqdm import tqdm
obs_total = [] 
acts_total = []
control_time = 100
# obs = env.reset()
for i in tqdm(range(control_time)):
    #take a step
    assert all(len(x) == len(env) for x in _acts.values())
    acts = {k: v for k, v in _acts.items() if not k.startswith('log_')}
    obs = env.step(acts)

    #read observation
    obs = {k: convert(v) for k, v in obs.items()}
    assert all(len(x) == len(env) for x in obs.values()), obs
    acts, _state = policy(obs, _state)
    acts = {k: convert(v) for k, v in acts.items()}
    
    acts['reset'] = obs['is_last'].copy()
    _acts = acts
    acts_total.append(acts)
#     print(f"{i}: obs: ", obs)
    obs_total.append(obs)
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 74.34it/s]

# %%
print(acts_total[1])
# Out:
# {'action': array([[-0.17820172, -0.1909592 , -0.21455906,  0.01336741,  0.00022247,
#         -0.22126421,  0.19274572]], dtype=float32), 'log_entropy': array([0.], dtype=float32), 'reset': array([False])}

# %%
obs_total[1]['reward']
# Out:
# array([-0.394391], dtype=float32)

# %%
#Collecting Reward and observations
import matplotlib.pyplot as plt

obs_data = obs_total[0]['vector']
obs_reward = obs_total[0]['reward']
acts_data = acts_total[0]['action']
for i in range(1,control_time):
    obs_data   = np.concatenate((obs_data  , obs_total[i]['vector']), axis = 0)
    obs_reward = np.concatenate((obs_reward, obs_total[i]['reward']), axis = 0)
    acts_data  = np.concatenate((acts_data , acts_total[i]['action']) , axis = 0)

print("obs_data shape: ", obs_data.shape)
print("obs_reward shape: ", obs_reward.shape)
print("acts_data shape: ", acts_data.shape)
# Out:
# obs_data shape:  (100, 64)
# obs_reward shape:  (100,)
# acts_data shape:  (100, 7)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 1, 64)
y = np.linspace(0, 1, control_time)
X, Y = np.meshgrid(x, y)

plt.figure()
plt.contourf(x,y,obs_data[:control_time])

plt.figure()
plt.plot(np.linalg.norm(obs_data, axis = -1))

# %%
plt.plot(-obs_reward)
plt.xlabel("Timesteps")
plt.ylabel("negative Reward")
# Out:
# Text(0, 0.5, 'negative Reward')

# %%
plt.plot(acts_data)
# Out:
# [<matplotlib.lines.Line2D at 0x15085449af10>,
#  <matplotlib.lines.Line2D at 0x15085449af40>,
#  <matplotlib.lines.Line2D at 0x1508544dce50>,
#  <matplotlib.lines.Line2D at 0x1508546c2c70>,
#  <matplotlib.lines.Line2D at 0x1508544a51f0>,
#  <matplotlib.lines.Line2D at 0x1508544a52e0>,
#  <matplotlib.lines.Line2D at 0x1508544a53d0>]

# %% [markdown]
# #Evaluating world model

# %%
agent.agent.task_behavior.ac
# Out:
# ImagActorCritic(agent/task_behavior/ac)

# %%
dataset = agent.dataset(replay.dataset)

# %%
data_i = next(dataset)

# %%
data_i['is_first']
# Out:
# Array([[ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        ...,
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False,  True]], dtype=bool)

# %%
embodied.run.train(agent, env, replay, logger, args)
# Out:
# In embodied/run/train.py
# Logdir /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/logdir/notebook_test_ks
# Observation space:
#   vector           Space(dtype=float32, shape=(64,), low=-inf, high=inf)
#   reward           Space(dtype=float32, shape=(), low=-inf, high=inf)
#   is_first         Space(dtype=bool, shape=(), low=False, high=True)
#   is_last          Space(dtype=bool, shape=(), low=False, high=True)
#   is_terminal      Space(dtype=bool, shape=(), low=False, high=True)
# Action space:
#   action           Space(dtype=float32, shape=(7,), low=-1.0, high=1.0)
#   reset            Space(dtype=bool, shape=(), low=False, high=True)
# Prefill train dataset.
# Found existing checkpoint.
# Loading checkpoint: /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/logdir/notebook_test_ks/checkpoint.ckpt
# Loaded checkpoint from 4229 seconds ago.
# Start training loop.
# Tracing policy function.
# Tracing policy function.
# Tracing train function.
# (16, 64, 1024)
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 embodied.run.train(agent, env, replay, logger, args)                                         │
# │   2                                                                                              │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/dreamerv3/embodied/run/train.py │
# │ :115 in train                                                                                    │
# │                                                                                                  │
# │   112   policy = lambda *args: agent.policy(                                                     │
# │   113 │     *args, mode='explore' if should_expl(step) else 'train')                             │
# │   114   while step < args.steps:                                                                 │
# │ ❱ 115 │   driver(policy, steps=100)                                                              │
# │   116 │   if should_save(step):                                                                  │
# │   117 │     checkpoint.save()                                                                    │
# │   118   logger.write()                                                                           │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/dreamerv3/embodied/core/driver. │
# │ py:42 in __call__                                                                                │
# │                                                                                                  │
# │   39   def __call__(self, policy, steps=0, episodes=0):                                          │
# │   40 │   step, episode = 0, 0                                                                    │
# │   41 │   while step < steps or episode < episodes:                                               │
# │ ❱ 42 │     step, episode = self._step(policy, step, episode)                                     │
# │   43                                                                                             │
# │   44   def _step(self, policy, step, episode):                                                   │
# │   45                                                                                             │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/dreamerv3/embodied/core/driver. │
# │ py:70 in _step                                                                                   │
# │                                                                                                  │
# │   67 │   for i in range(len(self._env)):                                                         │
# │   68 │     trn = {k: v[i] for k, v in trns.items()}                                              │
# │   69 │     [self._eps[i][k].append(v) for k, v in trn.items()]                                   │
# │ ❱ 70 │     [fn(trn, i, **self._kwargs) for fn in self._on_steps]                                 │
# │   71 │     step += 1                                                                             │
# │   72 │   if obs['is_last'].any():                                                                │
# │   73 │     for i, done in enumerate(obs['is_last']):                                             │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/dreamerv3/embodied/core/driver. │
# │ py:70 in <listcomp>                                                                              │
# │                                                                                                  │
# │   67 │   for i in range(len(self._env)):                                                         │
# │   68 │     trn = {k: v[i] for k, v in trns.items()}                                              │
# │   69 │     [self._eps[i][k].append(v) for k, v in trn.items()]                                   │
# │ ❱ 70 │     [fn(trn, i, **self._kwargs) for fn in self._on_steps]                                 │
# │   71 │     step += 1                                                                             │
# │   72 │   if obs['is_last'].any():                                                                │
# │   73 │     for i, done in enumerate(obs['is_last']):                                             │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/dreamerv3/embodied/run/train.py │
# │ :83 in train_step                                                                                │
# │                                                                                                  │
# │    80 │   for _ in range(should_train(step)):                                                    │
# │    81 │     with timer.scope('dataset'):                                                         │
# │    82 │   │   batch[0] = next(dataset)                                                           │
# │ ❱  83 │     outs, state[0], mets = agent.train(batch[0], state[0])                               │
# │    84 │     metrics.add(mets, prefix='train')                                                    │
# │    85 │     if 'priority' in outs:                                                               │
# │    86 │   │   replay.prioritize(outs['key'], outs['priority'])                                   │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/contextlib.py:79 in      │
# │ inner                                                                                            │
# │                                                                                                  │
# │    76 │   │   @wraps(func)                                                                       │
# │    77 │   │   def inner(*args, **kwds):                                                          │
# │    78 │   │   │   with self._recreate_cm():                                                      │
# │ ❱  79 │   │   │   │   return func(*args, **kwds)                                                 │
# │    80 │   │   return inner                                                                       │
# │    81                                                                                            │
# │    82                                                                                            │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/dreamerv3/jaxagent.py:72 in     │
# │ train                                                                                            │
# │                                                                                                  │
# │    69 │   rng = self._next_rngs(self.train_devices)                                              │
# │    70 │   if state is None:                                                                      │
# │    71 │     state, self.varibs = self._init_train(self.varibs, rng, data['is_first'])            │
# │ ❱  72 │   (outs, state, mets), self.varibs = self._train(                                        │
# │    73 │   │   self.varibs, rng, data, state)                                                     │
# │    74 │   outs = self._convert_outs(outs, self.train_devices)                                    │
# │    75 │   self._updates.increment()                                                              │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/PhD_projects2/dreamer_flows/dreamer/dreamerv3/ninjax.py:208 in      │
# │ wrapper                                                                                          │
# │                                                                                                  │
# │   205 │     return state                                                                         │
# │   206 │   else:                                                                                  │
# │   207 │     selected = {k: v for k, v in state.items() if k in wrapper.keys}                     │
# │ ❱ 208 │     out, updated = apply(statics, selected, rng, *args, **kw)                            │
# │   209 │     return out, {**state, **updated}                                                     │
# │   210   return wrapper                                                                           │
# │   211                                                                                            │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/site-packages/jax/_src/t │
# │ raceback_util.py:179 in reraise_with_filtered_traceback                                          │
# │                                                                                                  │
# │   176   def reraise_with_filtered_traceback(*args, **kwargs):                                    │
# │   177 │   __tracebackhide__ = True                                                               │
# │   178 │   try:                                                                                   │
# │ ❱ 179 │     return fun(*args, **kwargs)                                                          │
# │   180 │   except Exception as e:                                                                 │
# │   181 │     mode = _filtering_mode()                                                             │
# │   182 │     if _is_under_reraiser(e) or mode == "off":                                           │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/site-packages/jax/_src/p │
# │ jit.py:298 in cache_miss                                                                         │
# │                                                                                                  │
# │    295                                                                                           │
# │    296   @api_boundary                                                                           │
# │    297   def cache_miss(*args, **kwargs):                                                        │
# │ ❱  298 │   outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(      │
# │    299 │   │   jit_info, *args, **kwargs)                                                        │
# │    300 │   executable = _read_most_recent_pjit_call_executable(jaxpr)                            │
# │    301 │   maybe_fastpath_data = _get_fastpath_data(                                             │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/site-packages/jax/_src/p │
# │ jit.py:176 in _python_pjit_helper                                                                │
# │                                                                                                  │
# │    173 │   args_flat = [*init_states, *args_flat]                                                │
# │    174                                                                                           │
# │    175   try:                                                                                    │
# │ ❱  176 │   out_flat = pjit_p.bind(*args_flat, **params)                                          │
# │    177   except pxla.DeviceAssignmentMismatchError as e:                                         │
# │    178 │   fails, = e.args                                                                       │
# │    179 │   api_name = 'jit' if params['resource_env'] is None else 'pjit'                        │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/site-packages/jax/_src/c │
# │ ore.py:2788 in bind                                                                              │
# │                                                                                                  │
# │   2785 │   │   │   │   │   default=None, key=lambda t: getattr(t, 'level', -1))                  │
# │   2786 │   top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level          │
# │   2787 │   │   │   │    else axis_main.with_cur_sublevel())                                      │
# │ ❱ 2788 │   return self.bind_with_trace(top_trace, args, params)                                  │
# │   2789                                                                                           │
# │   2790                                                                                           │
# │   2791 # ------------------- Jaxpr checking -------------------                                  │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/site-packages/jax/_src/c │
# │ ore.py:425 in bind_with_trace                                                                    │
# │                                                                                                  │
# │    422 │   return self.bind_with_trace(find_top_trace(args), args, params)                       │
# │    423                                                                                           │
# │    424   def bind_with_trace(self, trace, args, params):                                         │
# │ ❱  425 │   out = trace.process_primitive(self, map(trace.full_raise, args), params)              │
# │    426 │   return map(full_lower, out) if self.multiple_results else full_lower(out)             │
# │    427                                                                                           │
# │    428   def def_impl(self, impl):                                                               │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/site-packages/jax/_src/c │
# │ ore.py:913 in process_primitive                                                                  │
# │                                                                                                  │
# │    910   lift = sublift = pure                                                                   │
# │    911                                                                                           │
# │    912   def process_primitive(self, primitive, tracers, params):                                │
# │ ❱  913 │   return primitive.impl(*tracers, **params)                                             │
# │    914                                                                                           │
# │    915   def process_call(self, primitive, f, tracers, params):                                  │
# │    916 │   return primitive.impl(f, *tracers, **params)                                          │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/site-packages/jax/_src/p │
# │ jit.py:1488 in _pjit_call_impl                                                                   │
# │                                                                                                  │
# │   1485   has_explicit_sharding = _pjit_explicit_sharding(                                        │
# │   1486 │     in_shardings, out_shardings, None, None)                                            │
# │   1487   if xla_extension_version >= 226:                                                        │
# │ ❱ 1488 │   return xc._xla.pjit(                                                                  │
# │   1489 │   │   name, f, call_impl_cache_miss, [], [], donated_argnums,                           │
# │   1490 │   │   tree_util.dispatch_registry,                                                      │
# │   1491 │   │   pxla.shard_arg if xla_extension_version >= 229 else pxla.temp_shard_arg,  # type  │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/site-packages/jax/_src/p │
# │ jit.py:1471 in call_impl_cache_miss                                                              │
# │                                                                                                  │
# │   1468 │   │   │   │   │   in_shardings, out_shardings, resource_env,                            │
# │   1469 │   │   │   │   │   donated_invars, name, keep_unused, inline):                           │
# │   1470   def call_impl_cache_miss(*args_, **kwargs_):                                            │
# │ ❱ 1471 │   out_flat, compiled = _pjit_call_impl_python(                                          │
# │   1472 │   │   *args, jaxpr=jaxpr, in_shardings=in_shardings,                                    │
# │   1473 │   │   out_shardings=out_shardings, resource_env=resource_env,                           │
# │   1474 │   │   donated_invars=donated_invars, name=name, keep_unused=keep_unused,                │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/site-packages/jax/_src/p │
# │ jit.py:1427 in _pjit_call_impl_python                                                            │
# │                                                                                                  │
# │   1424 │   │   │   │   │   │     ("abstract args", map(xla.abstractify, args)),                  │
# │   1425 │   │   │   │   │   │     ("fingerprint", fingerprint))                                   │
# │   1426   try:                                                                                    │
# │ ❱ 1427 │   return compiled.unsafe_call(*args), compiled                                          │
# │   1428   except FloatingPointError as e:                                                         │
# │   1429 │   assert config.debug_nans.value or config.debug_infs.value  # compiled_fun can only r  │
# │   1430                                                                                           │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/site-packages/jax/_src/p │
# │ rofiler.py:335 in wrapper                                                                        │
# │                                                                                                  │
# │   332   @wraps(func)                                                                             │
# │   333   def wrapper(*args, **kwargs):                                                            │
# │   334 │   with TraceAnnotation(name, **decorator_kwargs):                                        │
# │ ❱ 335 │     return func(*args, **kwargs)                                                         │
# │   336 │   return wrapper                                                                         │
# │   337   return wrapper                                                                           │
# │   338                                                                                            │
# │                                                                                                  │
# │ /rds/general/user/pg221/home/anaconda3/envs/dreamer_flows/lib/python3.9/site-packages/jax/_src/i │
# │ nterpreters/pxla.py:1213 in __call__                                                             │
# │                                                                                                  │
# │   1210 │     sharded_runtime_token = results.consume_token()                                     │
# │   1211 │     self._handle_token_bufs(result_token_bufs, sharded_runtime_token)                   │
# │   1212 │   else:                                                                                 │
# │ ❱ 1213 │     results = self.xla_executable.execute_sharded(input_bufs)                           │
# │   1214 │   if dispatch.needs_check_special():                                                    │
# │   1215 │     out_arrays = results.disassemble_into_single_device_arrays()                        │
# │   1216 │     for arrays in out_arrays:                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
i = next(replay.dataset())
print(replay.online)
i.keys()
# Out:
# False
# dict_keys(['vector', 'reward', 'is_first', 'is_last', 'is_terminal', 'action', 'reset', 'id'])

# %%
print(np.min(i['action']))
# Out:
# -0.9980621

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 1, 64)
y = np.linspace(0, 1, 64)
X, Y = np.meshgrid(x, y)

plt.figure()
plt.contourf(x,y,i['vector'])

plt.figure()
plt.plot(np.linalg.norm(i['vector'], axis = -1))
plt.colorbar()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:9                                                                                    │
# │                                                                                                  │
# │    6 X, Y = np.meshgrid(x, y)                                                                    │
# │    7                                                                                             │
# │    8 plt.figure()                                                                                │
# │ ❱  9 plt.contourf(x,y,i['vector'])                                                               │
# │   10                                                                                             │
# │   11 plt.figure()                                                                                │
# │   12 plt.plot(np.linalg.norm(i['vector'], axis = -1))                                            │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: 'int' object is not subscriptable

# %%
replay.table.keys()
